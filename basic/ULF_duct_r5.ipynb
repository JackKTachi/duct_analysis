# %%
import ULF_duct_plot_detail as udp
import calc_integral_chorus as cic
import ULF_duct_plot_ver2 as udp2

download_trange = ['2017-04-09', '2017-04-10']

'ne_mgf',\
        'kvec_polar_132',\
        'erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_E_spectra_132',\
        'erg_mepe_l2_omniflux_FEDO',\
        'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_29.3keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_20.5keV','erg_mepe_l3_pa_FEDU_17.1keV','erg_mepe_l3_pa_FEDU_14.3keV','erg_mepe_l3_pa_FEDU_12.0keV',\
            'delta_z', 'erg_mgf_l2_magt_8sec','erg_mgf_l2_mag_8sec_MAF_x&y',\
            'erg_orb_l2_pos_rmlatmlt','erg_orb_l2_pos_eq' == udp2.ULF_duct_load(download_trange)
""" 
r5 = ['2017-04-09 12:00:00', '2017-04-09 12:30:00']
min = 0.1
max = 20
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r5, min, max)


f = 0.5
theta = 0
plot_trange = r5
udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)




import pytplot
import calc_stokes as cs
'erg_pwe_hfa_l2_spectra_e_mix','erg_pwe_ofa_l2_spec_E_spectra_merged', 'erg_pwe_ofa_l2_spec_B_spectra_merged', 'st_I_spec','st_V/I_spec', 'st_Q/I_spec','st_Q/I_spec_log0','st_U/I_spec','st_chi_spec', 'erg_mgf_l2_mag_64hz_sgi_x_interp', 'erg_mgf_l2_mag_64hz_sgi_y_interp', 'erg_mgf_l2_mag_64hz_sgi_z_interp' ==\
      cs.calc_stokes(download_trange, r5)

udp.plot_B_int_density('erg_pwe_ofa_l2_spec_B_spectra_132','st_Q/I_spec','erg_pwe_ofa_l2_spec_B_chorus_integrate','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',r5)

pytplot.options('erg_pwe_ofa_l2_spec_E_spectra_merged', opt_dict={'ytitle': 'E-spectra', 'ysubtitle': '[kHz]', 'ylog':0, 'yrange':[5, 20], 'zrange':[1e-2,1e-9], 'spec':1})
pytplot.tplot(['st_Q/I_spec_log0','erg_pwe_ofa_l2_spec_E_spectra_merged'])


udp.plot_B_int_z_xy('erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',r5)
 """
# Out:
# 17-Jun-23 16:48:46: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 17-Jun-23 16:48:46: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170409_v02_03.cdf
# 17-Jun-23 16:48:47: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 17-Jun-23 16:48:48: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/8sec/2017/04/
# 17-Jun-23 16:48:48: File is current: erg_data/satellite/erg/mgf/l2/8sec/2017/04/erg_mgf_l2_8sec_20170409_v03.04.cdf
# 17-Jun-23 16:48:48: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2017/
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Magnetic Field Experiment (MGF) Level 2 spin-averaged magnetic field data
#
# Information about ERG MGF
#
# PI:  Ayako Matsuoka
# Affiliation: Data Analysis Center for Geomagnetism and Space Magnetism, Graduate School of Science, Kyoto University, Kitashirakawa-Oiwake Cho, Sakyo-ku Kyoto 606-8502, Japan
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of MGF L2: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Mgf
# Contact: erg_mgf_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 17-Jun-23 16:48:48: File is current: erg_data/satellite/erg/orb/def/2017/erg_orb_l2_20170409_v03.cdf
# 17-Jun-23 16:48:48: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 17-Jun-23 16:48:48: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************
# 17-Jun-23 16:48:59: /home/jackkooki/Document/duct_analysis/basic/compressional_B.py:40: RuntimeWarning: invalid value encountered in divide
#   cos_th = data_200s_z/ data_200s_total
#
# 17-Jun-23 16:48:59: /home/jackkooki/Document/duct_analysis/basic/compressional_B.py:41: RuntimeWarning: invalid value encountered in divide
#   sin_th = np.sqrt(data_200s_x**2 + data_200s_y**2) / data_200s_total
#
# 17-Jun-23 16:48:59: /home/jackkooki/Document/duct_analysis/basic/compressional_B.py:43: RuntimeWarning: invalid value encountered in divide
#   cos_ph = data_200s_x/ np.sqrt(data_200s_x**2 + data_200s_y**2)
#
# 17-Jun-23 16:48:59: /home/jackkooki/Document/duct_analysis/basic/compressional_B.py:44: RuntimeWarning: invalid value encountered in divide
#   sin_ph = data_200s_y / np.sqrt(data_200s_x**2 + data_200s_y**2)
#
# 17-Jun-23 16:48:59: tinterpol (linear) was applied to: cos_th_intpl
# 17-Jun-23 16:48:59: tinterpol (linear) was applied to: sin_th_intpl
# 17-Jun-23 16:48:59: tinterpol (linear) was applied to: cos_ph_intpl
# 17-Jun-23 16:48:59: tinterpol (linear) was applied to: sin_ph_intpl
# 17-Jun-23 16:48:59: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_x_intpl
# 17-Jun-23 16:48:59: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_y_intpl
# 17-Jun-23 16:48:59: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_z_intpl
# 17-Jun-23 16:49:12: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mepe/l2/omniflux/2017/04/
# 17-Jun-23 16:49:12: File is current: erg_data/satellite/erg/mepe/l2/omniflux/2017/04/erg_mepe_l2_omniflux_20170409_v01_02.cdf
# 17-Jun-23 16:49:12: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 17-Jun-23 16:49:12: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2017/
# 17-Jun-23 16:49:12: File is current: erg_data/satellite/erg/orb/def/2017/erg_orb_l2_20170409_v03.cdf
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Medium Energy Particle experiments - electron analyzer (MEP-e) electron omni flux data
#
# PI:  Satoshi Kasahara
# Affiliation: The University of Tokyo
#
# - The rules of the road (RoR) common to the ERG project:
#       https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# - RoR for MEP-e data:  https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Mepe
#
# Contact: erg_mep_info at isee.nagoya-u.ac.jp
# **************************************************************************
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************
# " \nr5 = ['2017-04-09 12:00:00', '2017-04-09 12:30:00']\nmin = 0.1\nmax = 20\n'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r5, min, max)\n\n\nf = 0.5\ntheta = 0\nplot_trange = r5\nudp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)\n\n\n\n\nimport pytplot\nimport calc_stokes as cs\n'erg_pwe_hfa_l2_spectra_e_mix','erg_pwe_ofa_l2_spec_E_spectra_merged', 'erg_pwe_ofa_l2_spec_B_spectra_merged', 'st_I_spec','st_V/I_spec', 'st_Q/I_spec','st_Q/I_spec_log0','st_U/I_spec','st_chi_spec', 'erg_mgf_l2_mag_64hz_sgi_x_interp', 'erg_mgf_l2_mag_64hz_sgi_y_interp', 'erg_mgf_l2_mag_64hz_sgi_z_interp' ==      cs.calc_stokes(download_trange, r5)\n\nudp.plot_B_int_density('erg_pwe_ofa_l2_spec_B_spectra_132','st_Q/I_spec','erg_pwe_ofa_l2_spec_B_chorus_integrate','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',r5)\n\npytplot.options('erg_pwe_ofa_l2_spec_E_spectra_merged', opt_dict={'ytitle': 'E-spectra', 'ysubtitle': '[kHz]', 'ylog':0, 'yrange':[5, 20], 'zrange':[1e-2,1e-9], 'spec':1})\npytplot.tplot(['st_Q/I_spec_log0','erg_pwe_ofa_l2_spec_E_spectra_merged'])\n\n\nudp.plot_B_int_z_xy('erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',r5)\n "

# %%
tr1 = ['2017-04-09 05:25:00', '2017-04-09 05:55:00']
udp.ULF_eventsearch_plot('kvec_polar_132',\
        'erg_pwe_ofa_l2_spec_B_spectra_132','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y', 'erg_mgf_l2_magt_8sec',\
            'erg_orb_l2_pos_rmlatmlt',tr1)
# Out:
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 17-Jun-23 16:49:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))

# %%
import plasma_params as pp
import numpy as np
fc = (pp.Q*330e-9/pp.ME)/2/np.pi
fofc = (1e3)/fc
fofc
# Out:
# 0.10839684652102054

# %%
import get_density as gd
import calc_RI as cr
import pytplot
import pyspedas
import numpy as np


r5 = ['2017-04-09 05:25:00', '2017-04-09 05:55:00']
min = 0.1
max = 20
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r5, min, max)

f = 0.3e3
path = './erg_data/satellite/erg/UHRdensity/2017/03/density20170327.txt'
theta = 0
plot_trange = r5
'ne' == gd.get_density(path)

pyspedas.tinterpol('ne', 'erg_mgf_l2_magt_8sec', newname='ne_intpl')
N=2*10**6
#N = pytplot.data_quants['ne_intpl']*1e6
B = pytplot.data_quants['erg_mgf_l2_magt_8sec']*1e-9

mu = cr.calc_RI(N, B, f)
pytplot.store_data('mu', data={'x':B['time'], 'y':mu})
pytplot.options('kvec_polar_132', opt_dict={'ytitle':'wna','ysubtitle':'[kHz]','ylog':1, 'spec':1})
pytplot.options('erg_pwe_ofa_l2_spec_B_spectra_132', opt_dict={'ytitle':'ofa-B','ysubtitle':'[kHz]','ylog':1, 'zlog':1, 'spec':1})
pytplot.options('erg_pwe_ofa_l2_spec_B_chorus_integrate', opt_dict={'ytitle':'integral','ylog':0})
pytplot.options('delta_z', opt_dict={'ytitle':'$\delta B$','ylog':0})
pytplot.options('erg_mgf_l2_magt_8sec', opt_dict={'ytitle':'$B_{total}$','ylog':0})
pytplot.options('erg_mgf_l2_mag_8sec_MAF_x&y', opt_dict={'ytitle':'$B_{xy}$','ylog':0})
pytplot.options('mu', opt_dict={'ytitle':'$\mu$','ylog':1})
plot_trange = r5
labels = pytplot.split_vec( 'erg_orb_l2_pos_rmlatmlt' )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_x', opt_dict={'ytitle':'L [Re]','ytitle_location':'left'} )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_y', 'ytitle', 'MLat [deg]' )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_z', 'ytitle', 'MLT [h]' )
pytplot.options('ne', opt_dict={'ytitle':'density','ylog':0, 'yrange':[1e-1, 5e-1]})
pytplot.xlim( plot_trange[0], plot_trange[1] )

pytplot.tplot(['kvec_polar_132', 'erg_pwe_ofa_l2_spec_B_spectra_132', 'erg_pwe_ofa_l2_spec_B_chorus_integrate', 'mu', 'delta_z', 'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y'],var_label=labels, xsize=10, ysize=20)
# Out:
# 16-Jun-23 21:03:05: <>:29: DeprecationWarning: invalid escape sequence '\d'
#
# 16-Jun-23 21:03:05: <>:32: DeprecationWarning: invalid escape sequence '\m'
#
# 16-Jun-23 21:03:05: <>:29: DeprecationWarning: invalid escape sequence '\d'
#
# 16-Jun-23 21:03:05: <>:32: DeprecationWarning: invalid escape sequence '\m'
#
# 16-Jun-23 21:03:05: /tmp/ipykernel_8620/871603064.py:29: DeprecationWarning: invalid escape sequence '\d'
#   pytplot.options('delta_z', opt_dict={'ytitle':'$\delta B$','ylog':0})
#
# 16-Jun-23 21:03:05: /tmp/ipykernel_8620/871603064.py:32: DeprecationWarning: invalid escape sequence '\m'
#   pytplot.options('mu', opt_dict={'ytitle':'$\mu$','ylog':1})
#
# 16-Jun-23 21:03:05: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 16-Jun-23 21:03:05: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170409_v02_03.cdf
# 16-Jun-23 21:03:06: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 16-Jun-23 21:06:39: tinterpol (linear) was applied to: ne_intpl
# 16-Jun-23 21:06:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 16-Jun-23 21:06:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 16-Jun-23 21:06:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 16-Jun-23 21:06:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 16-Jun-23 21:06:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))

# %%
import pyspedas
from pyspedas.erg import pwe_ofa
pwe_ofa(trange=download_trange)
pytplot.ylim('erg_pwe_ofa_l2_spec_B_spectra_132', 0.064, 0.704)
pytplot.tplot('erg_pwe_ofa_l2_spec_B_spectra_132')
# Out:
# 05-Jun-23 12:24:15: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 05-Jun-23 12:24:15: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170409_v02_03.cdf
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************

# %%
datat = pytplot.data_quants['erg_pwe_ofa_l2_spec_B_spectra_132']
pytplot.store_data('erg_pwe_ofa_l2_spec_B_spectra_132', data={'x': datat['time'], 'y': datat, 'v': datat['spec_bins']})

pytplot.options('erg_pwe_ofa_l2_spec_B_spectra_132', opt_dict={'ytitle': 'B-spectra', 'ysubtitle': '[kHz]', 'ylog':1, 'yrange':[0.064, 0.704],'spec':1, 'zlog':1,'zrange':[1e2,1e-4]})
pytplot.ylim('erg_pwe_ofa_l2_spec_B_spectra_132', 0.064, 0.704)
pytplot.tplot('erg_pwe_ofa_l2_spec_B_spectra_132')

# %%
pytplot.ylim('erg_pwe_ofa_l2_spec_B_spectra_132', 0.064, 0.768)
pytplot.tplot('erg_pwe_ofa_l2_spec_B_spectra_132')

# %%
pytplot.ylim('erg_pwe_ofa_l2_spec_B_spectra_132', 0.768, 2)
pytplot.tplot('erg_pwe_ofa_l2_spec_B_spectra_132')
