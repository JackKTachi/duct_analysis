# %%
import numpy as np


np.arctan(1.5/5.6)*180/np.pi
# Out:
# 14.995079129175988

# %%
np.arctan(3/15)*180/np.pi
# Out:
# 11.309932474020213

# %%
import plot_B1oscillation as pbo

tr = ['2017-04-13 19:30:00', '2017-04-13 20:10:00']
pbo.plotB1(tr, 1000)
# Out:
# 11-Jul-23 11:01:52: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 11-Jul-23 11:01:52: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170413_v02_03.cdf
# 11-Jul-23 11:01:53: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
import pyspedas
import pytplot

# %%
tr = ['2017-03-29 01:00:00','2017-03-29 01:30:00']

from pyspedas.erg import mgf
mgf(trange=tr)
# Out:
# 27-Jun-23 15:47:13: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/8sec/2017/03/
# 27-Jun-23 15:47:13: File is current: erg_data/satellite/erg/mgf/l2/8sec/2017/03/erg_mgf_l2_8sec_20170329_v03.04.cdf
# 27-Jun-23 15:47:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 27-Jun-23 15:47:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# **************************************************************************
# ...

# %%
pytplot.split_vec('erg_mgf_l2_mag_8sec_gse')
# Out:
# ['erg_mgf_l2_mag_8sec_gse_x',
#  'erg_mgf_l2_mag_8sec_gse_y',
#  'erg_mgf_l2_mag_8sec_gse_z']

# %%
import numpy as np
x = pytplot.data_quants['erg_mgf_l2_mag_8sec_gse_x']
y = pytplot.data_quants['erg_mgf_l2_mag_8sec_gse_y']
z = pytplot.data_quants['erg_mgf_l2_mag_8sec_gse_z']
total = np.sqrt(x**2 + y**2 + z**2)
pytplot.store_data('erg_mgf_l2_mag_8sec_gse_total', data={'x': pytplot.data_quants['erg_mgf_l2_mag_8sec_gse_x']['time'], 'y': total})
# Out:
# True

# %%
pytplot.tplot(['erg_mgf_l2_mag_8sec_gse_total', 'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_gse_z'])

# %%
import pyspedas
import pytplot
import numpy as np

# %%
tr = ['2017-03-29 01:00:00','2017-03-29 01:30:00']

from pyspedas.erg import pwe_efd
pwe_efd(trange=tr)
# Out:
# 12-Jun-23 16:53:48: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/efd/l2/E_spin/2017/03/
# 12-Jun-23 16:53:48: Downloading https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/efd/l2/E_spin/2017/03/erg_pwe_efd_l2_E_spin_20170329_v05_01.cdf to erg_data/satellite/erg/pwe/efd/l2/E_spin/2017/03/erg_pwe_efd_l2_E_spin_20170329_v05_01.cdf
# 12-Jun-23 16:53:49: Download complete: erg_data/satellite/erg/pwe/efd/l2/E_spin/2017/03/erg_pwe_efd_l2_E_spin_20170329_v05_01.cdf
# 12-Jun-23 16:53:49: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# ...

# %%
pytplot.tplot('erg_pwe_efd_l2_E_spin_Ev_dsi')
