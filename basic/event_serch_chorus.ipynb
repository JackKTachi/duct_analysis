# %%
import plot_B1oscillation as pbo

tr = ['2017-05-15 21:10:00','2017-05-15 21:40:00']
pbo.plotB1(tr, 200)
# Out:
# 05-Jul-23 09:24:56: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/05/
# 05-Jul-23 09:24:57: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/05/erg_pwe_ofa_l2_spec_20170515_v02_03.cdf
# 05-Jul-23 09:24:57: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
import plot_B1oscillation as pbo

tr = ['2017-05-23 06:00:00','2017-05-23 06:30:00']
pbo.plotB1(tr, 400)
# Out:
# 05-Jul-23 09:31:50: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/05/
# 05-Jul-23 09:31:50: Downloading https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/05/erg_pwe_ofa_l2_spec_20170523_v02_03.cdf to erg_data/satellite/erg/pwe/ofa/l2/spec/2017/05/erg_pwe_ofa_l2_spec_20170523_v02_03.cdf
# 05-Jul-23 09:32:01: Download complete: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/05/erg_pwe_ofa_l2_spec_20170523_v02_03.cdf
# 05-Jul-23 09:32:02: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# ...

# %%
import plot_B1oscillation as pbo

tr = ['2017-05-25 05:20:00','2017-05-25 05:50:00']
pbo.plotB1(tr, 400)
# Out:
# 05-Jul-23 09:36:28: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/05/
# 05-Jul-23 09:36:28: Downloading https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/05/erg_pwe_ofa_l2_spec_20170525_v02_03.cdf to erg_data/satellite/erg/pwe/ofa/l2/spec/2017/05/erg_pwe_ofa_l2_spec_20170525_v02_03.cdf
# 05-Jul-23 09:36:37: Download complete: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/05/erg_pwe_ofa_l2_spec_20170525_v02_03.cdf
# 05-Jul-23 09:36:38: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# ...

# %%
import plot_B1oscillation as pbo

tr = ['2017-05-26 00:45:00','2017-05-26 01:15:00']
pbo.plotB1(tr,450)
# Out:
# 05-Jul-23 09:41:05: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/05/
# 05-Jul-23 09:41:05: Downloading https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/05/erg_pwe_ofa_l2_spec_20170526_v02_03.cdf to erg_data/satellite/erg/pwe/ofa/l2/spec/2017/05/erg_pwe_ofa_l2_spec_20170526_v02_03.cdf
# 05-Jul-23 09:41:15: Download complete: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/05/erg_pwe_ofa_l2_spec_20170526_v02_03.cdf
# 05-Jul-23 09:41:15: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# ...

# %%
import plot_B1oscillation as pbo

tr = ['2017-05-28 07:15:00','2017-05-28 07:45:00']
pbo.plotB1(tr, 1000)
# Out:
# 05-Jul-23 09:45:41: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/05/
# 05-Jul-23 09:45:41: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/05/erg_pwe_ofa_l2_spec_20170528_v02_03.cdf
# 05-Jul-23 09:45:41: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
import plot_B1oscillation as pbo

tr = ['2017-05-28 20:30:00','2017-05-28 21:00:00']
pbo.plotB1(tr, 600)
# Out:
# 05-Jul-23 09:50:07: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/05/
# 05-Jul-23 09:50:07: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/05/erg_pwe_ofa_l2_spec_20170528_v02_03.cdf
# 05-Jul-23 09:50:08: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
import plot_B1oscillation as pbo

tr = ['2017-05-15 21:10:00','2017-05-15 21:40:00']
pbo.plotB1(tr, 200)

# %%
import plot_B1oscillation as pbo

tr = ['2017-05-15 21:10:00','2017-05-15 21:40:00']
pbo.plotB1(tr, 200)

# %%
import plot_B1oscillation as pbo

tr = ['2017-05-15 21:10:00','2017-05-15 21:40:00']
pbo.plotB1(tr, 200)
