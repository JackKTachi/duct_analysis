# %%
import ULF_duct_plot_detail as udp
import calc_integral_chorus as cic
import ULF_duct_plot_ver2 as udp2
import calc_stokes as cs
import calc_refractive_index as cri

download_trange = ['2017-03-27', '2013-03-28']

'ne_mgf',\
    'kvec_polar_132',\
        'erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_E_spectra_132',\
        'erg_mepe_l2_omniflux_FEDO',\
        'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_29.3keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_20.5keV','erg_mepe_l3_pa_FEDU_17.1keV','erg_mepe_l3_pa_FEDU_14.3keV','erg_mepe_l3_pa_FEDU_12.0keV',\
            'delta_z', 'erg_mgf_l2_magt_8sec','erg_mgf_l2_mag_8sec_MAF_x&y',\
            'erg_orb_l2_pos_rmlatmlt','erg_orb_l2_pos_eq' == udp2.ULF_duct_load(download_trange)
# Out:
# 04-Jul-23 22:48:17: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/03/
# 04-Jul-23 22:48:17: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/03/erg_pwe_ofa_l2_spec_20170327_v02_03.cdf
# 04-Jul-23 22:48:18: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jul-23 22:48:19: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/8sec/2017/03/
# 04-Jul-23 22:48:19: File is current: erg_data/satellite/erg/mgf/l2/8sec/2017/03/erg_mgf_l2_8sec_20170327_v03.04.cdf
# 04-Jul-23 22:48:19: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2017/
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Magnetic Field Experiment (MGF) Level 2 spin-averaged magnetic field data
#
# Information about ERG MGF
#
# PI:  Ayako Matsuoka
# Affiliation: Data Analysis Center for Geomagnetism and Space Magnetism, Graduate School of Science, Kyoto University, Kitashirakawa-Oiwake Cho, Sakyo-ku Kyoto 606-8502, Japan
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of MGF L2: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Mgf
# Contact: erg_mgf_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jul-23 22:48:19: File is current: erg_data/satellite/erg/orb/def/2017/erg_orb_l2_20170327_v03.cdf
# 04-Jul-23 22:48:19: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 04-Jul-23 22:48:19: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jul-23 22:48:31: tinterpol (linear) was applied to: cos_th_intpl
# 04-Jul-23 22:48:31: tinterpol (linear) was applied to: sin_th_intpl
# 04-Jul-23 22:48:31: tinterpol (linear) was applied to: cos_ph_intpl
# 04-Jul-23 22:48:31: tinterpol (linear) was applied to: sin_ph_intpl
# 04-Jul-23 22:48:31: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_x_intpl
# 04-Jul-23 22:48:31: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_y_intpl
# 04-Jul-23 22:48:31: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_z_intpl
# 04-Jul-23 22:48:44: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mepe/l2/omniflux/2017/03/
# 04-Jul-23 22:48:44: File is current: erg_data/satellite/erg/mepe/l2/omniflux/2017/03/erg_mepe_l2_omniflux_20170327_v01_02.cdf
# 04-Jul-23 22:48:44: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 04-Jul-23 22:48:44: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2017/
# 04-Jul-23 22:48:44: File is current: erg_data/satellite/erg/orb/def/2017/erg_orb_l2_20170327_v03.cdf
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Medium Energy Particle experiments - electron analyzer (MEP-e) electron omni flux data
#
# PI:  Satoshi Kasahara
# Affiliation: The University of Tokyo
#
# - The rules of the road (RoR) common to the ERG project:
#       https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# - RoR for MEP-e data:  https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Mepe
#
# Contact: erg_mep_info at isee.nagoya-u.ac.jp
# **************************************************************************
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************
# ('ne_mgf',
#  'kvec_polar_132',
#  'erg_pwe_ofa_l2_spec_B_spectra_132',
#  'erg_pwe_ofa_l2_spec_E_spectra_132',
#  'erg_mepe_l2_omniflux_FEDO',
#  'erg_mepe_l3_pa_FEDU_87.5keV',
#  'erg_mepe_l3_pa_FEDU_72.6keV',
#  'erg_mepe_l3_pa_FEDU_60.4keV',
#  'erg_mepe_l3_pa_FEDU_50.3keV',
#  'erg_mepe_l3_pa_FEDU_42.0keV',
#  'erg_mepe_l3_pa_FEDU_35.0keV',
#  'erg_mepe_l3_pa_FEDU_29.3keV',
#  'erg_mepe_l3_pa_FEDU_24.5keV',
#  'erg_mepe_l3_pa_FEDU_20.5keV',
#  'erg_mepe_l3_pa_FEDU_17.1keV',
#  'erg_mepe_l3_pa_FEDU_14.3keV',
#  'erg_mepe_l3_pa_FEDU_12.0keV',
#  'delta_z',
#  'erg_mgf_l2_magt_8sec',
#  'erg_mgf_l2_mag_8sec_MAF_x&y',
#  'erg_orb_l2_pos_rmlatmlt',
#  False)

# %%
import get_density as gd
import calc_RI as cr
import pytplot
import pyspedas
import numpy as np


r2 = ['2017-03-27 21:30:00', '2017-03-27 22:00:00']
min = 0.1
max = 20
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r2, min, max)

f = 0.3e3
path = './erg_data/satellite/erg/UHRdensity/2017/03/density20170327.txt'
theta = 0
plot_trange = r2
'ne' == gd.get_density(path)

pyspedas.tinterpol('ne', 'erg_mgf_l2_magt_8sec', newname='ne_intpl')
N=2*10**6
#N = pytplot.data_quants['ne_intpl']*1e6
B = pytplot.data_quants['erg_mgf_l2_magt_8sec']*1e-9

mu = cr.calc_RI(N, B, f)
pytplot.store_data('mu', data={'x':B['time'], 'y':mu})
pytplot.options('kvec_polar_132', opt_dict={'ytitle':'wna','ysubtitle':'[kHz]','ylog':1, 'spec':1})
pytplot.options('erg_pwe_ofa_l2_spec_B_spectra_132', opt_dict={'ytitle':'ofa-B','ysubtitle':'[kHz]','ylog':1, 'zlog':1, 'spec':1})
pytplot.options('erg_pwe_ofa_l2_spec_B_chorus_integrate', opt_dict={'ytitle':'chorus intensity', 'ysubtitle':'[$pT^2$]','ylog':1})
pytplot.options('delta_z', opt_dict={'ytitle':'$\delta B$','ylog':0})
pytplot.options('erg_mgf_l2_magt_8sec', opt_dict={'ytitle':'$B_{total}$','ylog':0})
pytplot.options('erg_mgf_l2_mag_8sec_MAF_x&y', opt_dict={'ytitle':'$B_{xy}$','ylog':0})
pytplot.options('mu', opt_dict={'ytitle':'$\mu$','ylog':1})
plot_trange = r2
labels = pytplot.split_vec( 'erg_orb_l2_pos_rmlatmlt' )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_x', opt_dict={'ytitle':'L [Re]','ytitle_location':'left'} )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_y', 'ytitle', 'MLat [deg]' )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_z', 'ytitle', 'MLT [h]' )
pytplot.options('ne', opt_dict={'ytitle':'density','ylog':0, 'yrange':[1e-1, 5e-1]})
pytplot.xlim( plot_trange[0], plot_trange[1] )

pytplot.tplot(['kvec_polar_132', 'erg_pwe_ofa_l2_spec_B_spectra_132', 'erg_pwe_ofa_l2_spec_B_chorus_integrate', 'mu', 'delta_z', 'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y'],var_label=labels, xsize=10, ysize=20)
# Out:
# 04-Jul-23 22:48:45: <>:29: DeprecationWarning: invalid escape sequence '\d'
#
# 04-Jul-23 22:48:45: <>:32: DeprecationWarning: invalid escape sequence '\m'
#
# 04-Jul-23 22:48:45: <>:29: DeprecationWarning: invalid escape sequence '\d'
#
# 04-Jul-23 22:48:45: <>:32: DeprecationWarning: invalid escape sequence '\m'
#
# 04-Jul-23 22:48:45: /tmp/ipykernel_24141/737114753.py:29: DeprecationWarning: invalid escape sequence '\d'
#   pytplot.options('delta_z', opt_dict={'ytitle':'$\delta B$','ylog':0})
#
# 04-Jul-23 22:48:45: /tmp/ipykernel_24141/737114753.py:32: DeprecationWarning: invalid escape sequence '\m'
#   pytplot.options('mu', opt_dict={'ytitle':'$\mu$','ylog':1})
#
# 04-Jul-23 22:48:45: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/03/
# 04-Jul-23 22:48:45: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/03/erg_pwe_ofa_l2_spec_20170327_v02_03.cdf
# 04-Jul-23 22:48:45: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jul-23 22:52:40: tinterpol (linear) was applied to: ne_intpl
# 04-Jul-23 22:52:40: erg_mgf_l2_mag_8sec_MAF_x&y is currently not in pytplot.
# 04-Jul-23 22:52:40: The name erg_mgf_l2_mag_8sec_MAF_x&y is currently not in pytplot
# 04-Jul-23 22:52:40: The name erg_mgf_l2_mag_8sec_MAF_x&y is currently not in pytplot
# 04-Jul-23 22:52:40: Variable not found: erg_mgf_l2_mag_8sec_MAF_x&y
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:52:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))

# %%
import compressional_B as cb

tr = ['2017-03-27 21:30:00', '2017-03-27 22:00:00']
'B_perp_para','delta_z', 'B_perp', 'erg_mgf_l2_magt_8sec', 'ULF_wna','cos_th_intpl' == cb.ULFwna(tr)
# Out:
# 04-Jul-23 22:52:41: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/8sec/2017/03/
# 04-Jul-23 22:52:41: File is current: erg_data/satellite/erg/mgf/l2/8sec/2017/03/erg_mgf_l2_8sec_20170327_v03.04.cdf
# 04-Jul-23 22:52:42: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 04-Jul-23 22:52:42: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# 04-Jul-23 22:52:42: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2017/
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Magnetic Field Experiment (MGF) Level 2 spin-averaged magnetic field data
#
# Information about ERG MGF
#
# PI:  Ayako Matsuoka
# Affiliation: Data Analysis Center for Geomagnetism and Space Magnetism, Graduate School of Science, Kyoto University, Kitashirakawa-Oiwake Cho, Sakyo-ku Kyoto 606-8502, Japan
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of MGF L2: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Mgf
# Contact: erg_mgf_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jul-23 22:52:42: File is current: erg_data/satellite/erg/orb/def/2017/erg_orb_l2_20170327_v03.cdf
# 04-Jul-23 22:52:42: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 04-Jul-23 22:52:42: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jul-23 22:52:54: tinterpol (linear) was applied to: cos_th_intpl
# 04-Jul-23 22:52:54: tinterpol (linear) was applied to: sin_th_intpl
# 04-Jul-23 22:52:54: tinterpol (linear) was applied to: cos_ph_intpl
# 04-Jul-23 22:52:54: tinterpol (linear) was applied to: sin_ph_intpl
# 04-Jul-23 22:52:54: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_x_intpl
# 04-Jul-23 22:52:54: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_y_intpl
# 04-Jul-23 22:52:54: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_z_intpl
# ('B_perp_para', 'delta_z', 'B_perp', 'erg_mgf_l2_magt_8sec', 'ULF_wna', False)

# %%
import pytplot  
pytplot.xlim( tr[0], tr[1] )
pytplot.tplot(['delta_z','ULF_wna','erg_mgf_l2_mag_8sec_MAF_x&y', 'erg_mgf_l2_magt_8sec'], xsize=10, ysize=20)
# Out:
# 04-Jul-23 22:53:19: The name erg_mgf_l2_mag_8sec_MAF_x&y is currently not in pytplot
# 04-Jul-23 22:53:19: The name erg_mgf_l2_mag_8sec_MAF_x&y is currently not in pytplot
# 04-Jul-23 22:53:19: Variable not found: erg_mgf_l2_mag_8sec_MAF_x&y

# %%
import pyspedas
import pytplot 
import numpy as np
from pytplot.tplot import tplot

from pyspedas.erg import mgf
mgf(trange = tr)

from pyspedas.erg import orb
orb(trange = tr)

import numpy as np
import pytplot

pytplot.split_vec('erg_mgf_l2_mag_8sec_gsm')

data_x = pytplot.data_quants['erg_mgf_l2_mag_8sec_gsm_x']
data_y = pytplot.data_quants['erg_mgf_l2_mag_8sec_gsm_y']
data_z = pytplot.data_quants['erg_mgf_l2_mag_8sec_gsm_z']
average_spin = 25

data_200s_total = np.zeros(data_x['time'].size)
data_200s_x = np.zeros(data_x['time'].size)
data_200s_y = np.zeros(data_x['time'].size)
data_200s_z = np.zeros(data_x['time'].size)

for i in range(data_x['time'].size):
    idx = np.arange(i-average_spin//2, i+average_spin//2+1).astype(int)
    idx = np.clip(idx, 0, data_x['time'].size-1)

    data_200s_x[i] = np.sum(data_x[idx]) / average_spin
    data_200s_y[i] = np.sum(data_y[idx]) / average_spin
    data_200s_z[i] = np.sum(data_z[idx]) / average_spin
    data_200s_total[i] = np.sqrt(data_200s_x[i]**2 + data_200s_y[i]**2 + data_200s_z[i]**2)

pytplot.split_vec('erg_orb_l2_pos_rmlatmlt')

cos_th = data_200s_z/ data_200s_total
sin_th = np.sqrt(data_200s_x**2 + data_200s_y**2) / data_200s_total

cos_ph = data_200s_x/ np.sqrt(data_200s_x**2 + data_200s_y**2)
sin_ph = data_200s_y / np.sqrt(data_200s_x**2 + data_200s_y**2)

beta = pytplot.data_quants['erg_orb_l2_pos_rmlatmlt_y'] * np.pi / 180.0
alph = np.pi * pytplot.data_quants['erg_orb_l2_pos_rmlatmlt_z'] / 12.0

cos_alph = np.cos(alph)
sin_alph = np.sin(alph)
cos_beta = np.cos(beta)
sin_beta = np.sin(beta)

pytplot.store_data('cos_th', data={'x': data_x['time'], 'y': cos_th})
pytplot.store_data('sin_th', data={'x': data_x['time'], 'y': sin_th})
pytplot.store_data('cos_ph', data={'x': data_x['time'], 'y': cos_ph})
pytplot.store_data('sin_ph', data={'x': data_x['time'], 'y': sin_ph})
pytplot.store_data('cos_alph', data={'x': pytplot.data_quants['erg_orb_l2_pos_rmlatmlt_x']['time'], 'y': cos_alph})
pytplot.store_data('sin_alph', data={'x': pytplot.data_quants['erg_orb_l2_pos_rmlatmlt_x']['time'], 'y': sin_alph})
pytplot.store_data('cos_beta', data={'x': pytplot.data_quants['erg_orb_l2_pos_rmlatmlt_x']['time'], 'y': cos_beta})
pytplot.store_data('sin_beta', data={'x': pytplot.data_quants['erg_orb_l2_pos_rmlatmlt_x']['time'], 'y': sin_beta})

pyspedas.tinterpol('cos_th', 'cos_alph', newname='cos_th_intpl')
pyspedas.tinterpol('sin_th', 'cos_alph', newname='sin_th_intpl')
pyspedas.tinterpol('cos_ph', 'cos_alph', newname='cos_ph_intpl')
pyspedas.tinterpol('sin_ph', 'cos_alph', newname='sin_ph_intpl')

gamma = np.arctan((pytplot.data_quants['cos_beta']*(pytplot.data_quants['cos_alph']*pytplot.data_quants['sin_ph_intpl']-pytplot.data_quants['sin_alph']*pytplot.data_quants['cos_ph_intpl']))/(pytplot.data_quants['cos_th_intpl']*pytplot.data_quants['cos_beta']*(pytplot.data_quants['cos_alph']*pytplot.data_quants['cos_ph_intpl']+pytplot.data_quants['sin_alph']*pytplot.data_quants['sin_ph_intpl'])+pytplot.data_quants['sin_th_intpl']*pytplot.data_quants['sin_beta']))

pyspedas.tinterpol('erg_mgf_l2_mag_8sec_gsm_x', 'cos_alph', newname='erg_mgf_l2_mag_8sec_gsm_x_intpl')
pyspedas.tinterpol('erg_mgf_l2_mag_8sec_gsm_y', 'cos_alph', newname='erg_mgf_l2_mag_8sec_gsm_y_intpl')
pyspedas.tinterpol('erg_mgf_l2_mag_8sec_gsm_z', 'cos_alph', newname='erg_mgf_l2_mag_8sec_gsm_z_intpl')

B_MFA_z = pytplot.data_quants['sin_th_intpl'] * pytplot.data_quants['cos_ph_intpl'] * pytplot.data_quants['erg_mgf_l2_mag_8sec_gsm_x_intpl'] + pytplot.data_quants['sin_th_intpl'] * pytplot.data_quants['sin_ph_intpl'] * pytplot.data_quants['erg_mgf_l2_mag_8sec_gsm_y_intpl'] + pytplot.data_quants['cos_th_intpl'] * pytplot.data_quants['erg_mgf_l2_mag_8sec_gsm_z_intpl']

delta_B = np.zeros(B_MFA_z.size)

for i in range(B_MFA_z.size):
    idx1 = np.arange(i-average_spin//2, i+average_spin//2+1).astype(int)
    idx1 = np.clip(idx1, 0, B_MFA_z.size-1)
    delta_B[i] =  B_MFA_z[i] - np.sum(B_MFA_z[idx1]) / average_spin

B_MFA_x = pytplot.data_quants['erg_mgf_l2_mag_8sec_gsm_x_intpl'] * (np.cos(gamma) * pytplot.data_quants['cos_th_intpl'] * pytplot.data_quants['cos_ph_intpl'] + np.sin(gamma) * pytplot.data_quants['sin_ph_intpl']) + pytplot.data_quants['erg_mgf_l2_mag_8sec_gsm_y_intpl'] * (np.cos(gamma) * pytplot.data_quants['cos_th_intpl'] * pytplot.data_quants['sin_ph_intpl'] - np.sin(gamma) * pytplot.data_quants['cos_ph_intpl']) - pytplot.data_quants['erg_mgf_l2_mag_8sec_gsm_z_intpl'] * np.cos(gamma) * pytplot.data_quants['sin_th_intpl']
B_MFA_y = pytplot.data_quants['erg_mgf_l2_mag_8sec_gsm_x_intpl'] * (np.sin(gamma) * pytplot.data_quants['cos_th_intpl'] * pytplot.data_quants['cos_ph_intpl'] - np.cos(gamma) * pytplot.data_quants['sin_ph_intpl']) + pytplot.data_quants['erg_mgf_l2_mag_8sec_gsm_y_intpl'] * (np.sin(gamma) * pytplot.data_quants['cos_th_intpl'] * pytplot.data_quants['sin_ph_intpl'] + np.cos(gamma) * pytplot.data_quants['cos_ph_intpl']) - pytplot.data_quants['erg_mgf_l2_mag_8sec_gsm_z_intpl'] * np.sin(gamma) * pytplot.data_quants['sin_th_intpl']

B_MFA_xy = np.zeros((B_MFA_x['time'].size))
for i in range(B_MFA_x['time'].size):
    B_MFA_xy[i] = B_MFA_x[i] + B_MFA_y[i]

theta = np.zeros(B_MFA_x['time'].size)
for i in range(B_MFA_x['time'].size):
    theta[i] = np.arctan(-delta_B[i]/B_MFA_xy[i])*180/np.pi

pytplot.store_data('delta_z', data={'x': pytplot.data_quants['sin_th_intpl']['time'], 'y': delta_B})
pytplot.store_data('B_perp', data={'x': pytplot.data_quants['sin_th_intpl']['time'], 'y': B_MFA_xy})
pytplot.store_data('ULF_wna', data={'x': pytplot.data_quants['sin_th_intpl']['time'], 'y': theta})

pytplot.options('B_perp', opt_dict={'legend_names': [r'$B_\perp$'], 'ytitle': r'$B_\perp$', 'ysubtitle': '[nT]'})
pytplot.options('delta_z', opt_dict={'legend_names': ['$_\parallel$'], 'ytitle': '$B_\parallel$', 'ysubtitle': '[nT]'})
pytplot.options('erg_mgf_l2_magt_8sec', opt_dict={'ytitle': r'$Btotal$', 'ysubtitle': '[nT]'})
pytplot.options('ULF_wna', opt_dict={'ytitle': r'$\theta$', 'ysubtitle': '[degree]'})
# Out:
# 04-Jul-23 22:53:19: <>:97: DeprecationWarning: invalid escape sequence '\p'
#
# 04-Jul-23 22:53:19: <>:97: DeprecationWarning: invalid escape sequence '\p'
#
# 04-Jul-23 22:53:19: <>:97: DeprecationWarning: invalid escape sequence '\p'
#
# 04-Jul-23 22:53:19: <>:97: DeprecationWarning: invalid escape sequence '\p'
#
# 04-Jul-23 22:53:19: /tmp/ipykernel_24141/3203469841.py:97: DeprecationWarning: invalid escape sequence '\p'
#   pytplot.options('delta_z', opt_dict={'legend_names': ['$_\parallel$'], 'ytitle': '$B_\parallel$', 'ysubtitle': '[nT]'})
#
# 04-Jul-23 22:53:19: /tmp/ipykernel_24141/3203469841.py:97: DeprecationWarning: invalid escape sequence '\p'
#   pytplot.options('delta_z', opt_dict={'legend_names': ['$_\parallel$'], 'ytitle': '$B_\parallel$', 'ysubtitle': '[nT]'})
#
# 04-Jul-23 22:53:19: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/8sec/2017/03/
# 04-Jul-23 22:53:19: File is current: erg_data/satellite/erg/mgf/l2/8sec/2017/03/erg_mgf_l2_8sec_20170327_v03.04.cdf
# 04-Jul-23 22:53:19: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 04-Jul-23 22:53:19: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# 04-Jul-23 22:53:20: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2017/
# 04-Jul-23 22:53:20: File is current: erg_data/satellite/erg/orb/def/2017/erg_orb_l2_20170327_v03.cdf
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Magnetic Field Experiment (MGF) Level 2 spin-averaged magnetic field data
#
# Information about ERG MGF
#
# PI:  Ayako Matsuoka
# Affiliation: Data Analysis Center for Geomagnetism and Space Magnetism, Graduate School of Science, Kyoto University, Kitashirakawa-Oiwake Cho, Sakyo-ku Kyoto 606-8502, Japan
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of MGF L2: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Mgf
# Contact: erg_mgf_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jul-23 22:53:20: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 04-Jul-23 22:53:20: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jul-23 22:53:31: tinterpol (linear) was applied to: cos_th_intpl
# 04-Jul-23 22:53:31: tinterpol (linear) was applied to: sin_th_intpl
# 04-Jul-23 22:53:31: tinterpol (linear) was applied to: cos_ph_intpl
# 04-Jul-23 22:53:31: tinterpol (linear) was applied to: sin_ph_intpl
# 04-Jul-23 22:53:31: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_x_intpl
# 04-Jul-23 22:53:31: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_y_intpl
# 04-Jul-23 22:53:31: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_z_intpl

# %%
import compressional_B as cb

# %%
tr = ['2017-03-27 21:30:00', '2017-03-27 22:00:00']
'B_perp_para', 'B1_total', 'delta_z', 'delta_xy', 'ULF_wna', 'erg_mgf_l2_magt_8sec', 'cos_th_intpl' == cb.ULFwna(tr)
import pytplot
pytplot.xlim( tr[0], tr[1] )
pytplot.tplot(['B_perp_para', 'B1_total', 'delta_z', 'delta_xy', 'ULF_wna', 'erg_mgf_l2_magt_8sec'], xsize=10, ysize=20)
# Out:
# 04-Jul-23 22:53:53: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/8sec/2017/03/
# 04-Jul-23 22:53:53: File is current: erg_data/satellite/erg/mgf/l2/8sec/2017/03/erg_mgf_l2_8sec_20170327_v03.04.cdf
# 04-Jul-23 22:53:53: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 04-Jul-23 22:53:53: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# 04-Jul-23 22:53:53: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2017/
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Magnetic Field Experiment (MGF) Level 2 spin-averaged magnetic field data
#
# Information about ERG MGF
#
# PI:  Ayako Matsuoka
# Affiliation: Data Analysis Center for Geomagnetism and Space Magnetism, Graduate School of Science, Kyoto University, Kitashirakawa-Oiwake Cho, Sakyo-ku Kyoto 606-8502, Japan
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of MGF L2: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Mgf
# Contact: erg_mgf_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jul-23 22:53:54: File is current: erg_data/satellite/erg/orb/def/2017/erg_orb_l2_20170327_v03.cdf
# 04-Jul-23 22:53:54: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 04-Jul-23 22:53:54: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jul-23 22:54:05: tinterpol (linear) was applied to: cos_th_intpl
# 04-Jul-23 22:54:05: tinterpol (linear) was applied to: sin_th_intpl
# 04-Jul-23 22:54:05: tinterpol (linear) was applied to: cos_ph_intpl
# 04-Jul-23 22:54:05: tinterpol (linear) was applied to: sin_ph_intpl
# 04-Jul-23 22:54:05: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_x_intpl
# 04-Jul-23 22:54:05: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_y_intpl
# 04-Jul-23 22:54:05: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_z_intpl
# 04-Jul-23 22:54:30: Substituting symbol \perp from STIXGeneral
# 04-Jul-23 22:54:30: Substituting symbol \perp from STIXGeneral
# 04-Jul-23 22:54:31: Substituting symbol \perp from STIXGeneral
# 04-Jul-23 22:54:31: Substituting symbol \perp from STIXGeneral

# %%
delta_B
# Out:
# array([1.58859839, 1.14745469, 0.94839244, ...,        nan,        nan,
#               nan])

# %%
B_perp_para = np.zeros((B_MFA_x['time'].size, 2))
for i in range(B_MFA_x['time'].size):
    B_perp_para[i,0] = delta_B[i]
    B_perp_para[i,1] = B_MFA_xy[i]

B1_total = np.zeros(B_MFA_x['time'].size)
for i in range(B_MFA_x['time'].size):
    B1_total[i] = delta_B[i] + B_MFA_xy[i]

pytplot.store_data('B_perp_para', data={'x': pytplot.data_quants['sin_th_intpl']['time'], 'y': B_perp_para})
pytplot.store_data('B1_total', data={'x': pytplot.data_quants['sin_th_intpl']['time'], 'y': B1_total})

pytplot.options('B_perp_para', opt_dict={'legend_names': [r'$B_\parallel$', r'$B_\perp$'], 'ytitle': r'$B1$', 'ysubtitle': '[nT]'})
pytplot.options('B1_total', opt_dict={'ytitle': r'$B_{1total}$', 'ysubtitle': '[nT]'})

pytplot.tplot(['B_perp_para', 'B1_total', 'ULF_wna', 'erg_mgf_l2_magt_8sec'], xsize=15, ysize=15)
# Out:
# 04-Jul-23 22:54:31: Substituting symbol \perp from STIXGeneral
# 04-Jul-23 22:54:31: Substituting symbol \perp from STIXGeneral
# 04-Jul-23 22:54:32: Substituting symbol \perp from STIXGeneral
# 04-Jul-23 22:54:32: Substituting symbol \perp from STIXGeneral

# %%
pytplot.xlim('2017-03-27 21:40:00', '2017-03-27 22:00:00')
pytplot.tplot(['kvec_polar_132', 'erg_pwe_ofa_l2_spec_B_spectra_132', 'erg_pwe_ofa_l2_spec_B_chorus_integrate', 'B1_total',  'delta_z'],var_label=labels, xsize=10, ysize=10)
# Out:
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jul-23 22:55:13: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))

# %%
pytplot.tplot(['delta_z', 'ULF_wna', 'B_perp', 'erg_mgf_l2_magt_8sec'],xsize=15, ysize=20)
# Out:
# 30-Jun-23 16:54:37: Substituting symbol \perp from STIXGeneral
# 30-Jun-23 16:54:37: Substituting symbol \perp from STIXGeneral
# 30-Jun-23 16:54:37: Substituting symbol \perp from STIXGeneral
# 30-Jun-23 16:54:37: Substituting symbol \perp from STIXGeneral
# 30-Jun-23 16:54:37: Substituting symbol \perp from STIXGeneral
# 30-Jun-23 16:54:37: Substituting symbol \perp from STIXGeneral
# 30-Jun-23 16:54:37: Substituting symbol \perp from STIXGeneral
# 30-Jun-23 16:54:37: Substituting symbol \perp from STIXGeneral

# %%
import plasma_params as pp
omega_i = pp.Q*pp.B0/pp.MH

# %%
import plasma_params as pp
pp.omega_o['value']
# Out:
# 0.8532235939643349
