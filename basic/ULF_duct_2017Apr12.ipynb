# %%
import ULF_duct_plot_ver1 as udp1

download_trange = ['2017-04-12', '2013-04-13']

'kvec_polar_132',\
        'erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_E_spectra_132',\
        'erg_mepe_l2_omniflux_FEDO',\
        'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_29.3keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_20.5keV','erg_mepe_l3_pa_FEDU_17.1keV','erg_mepe_l3_pa_FEDU_14.3keV','erg_mepe_l3_pa_FEDU_12.0keV',\
            'delta_z', 'erg_mgf_l2_magt_8sec','erg_mgf_l2_mag_8sec_MAF_x&y',\
            'erg_orb_l2_pos_rmlatmlt','erg_orb_l2_pos_eq' == udp1.ULF_duct_load(download_trange)
# Out:
# 23-May-23 00:55:38: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 23-May-23 00:55:39: Downloading https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170412_v02_03.cdf to erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170412_v02_03.cdf
# 23-May-23 00:55:45: Download complete: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170412_v02_03.cdf
# 23-May-23 00:55:46: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# ...

# %%
pr_1 = ['2017-04-12 00:00:00','2017-04-12 00:30:00']
udp1.ULF_duct_plot_12to50('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132', 'erg_pwe_ofa_l2_spec_E_spectra_132', 'erg_mepe_l2_omniflux_FEDO', 'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_12.0keV', 'delta_z', 'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y', 'erg_orb_l2_pos_rmlatmlt', pr_1)
# Out:
# 23-May-23 00:56:05: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 23-May-23 00:56:05: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
# ...

# %%
pr_2 = ['2017-04-12 00:30:00','2017-04-12 01:00:00']
udp1.ULF_duct_plot_12to50('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132', 'erg_pwe_ofa_l2_spec_E_spectra_132', 'erg_mepe_l2_omniflux_FEDO', 'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_12.0keV', 'delta_z', 'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y', 'erg_orb_l2_pos_rmlatmlt', pr_2)
# Out:
# 23-May-23 00:57:18: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 23-May-23 00:57:18: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
# ...

# %%
pr_3 = ['2017-04-12 05:00:00','2017-04-12 05:30:00']
udp1.ULF_duct_plot_12to50('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132', 'erg_pwe_ofa_l2_spec_E_spectra_132', 'erg_mepe_l2_omniflux_FEDO', 'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_12.0keV', 'delta_z', 'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y', 'erg_orb_l2_pos_rmlatmlt', pr_3)
# Out:
# 23-May-23 00:58:59: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 23-May-23 00:58:59: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
# ...

# %%
pr_4 = ['2017-04-12 05:30:00','2017-04-12 06:00:00']
udp1.ULF_duct_plot_12to50('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132', 'erg_pwe_ofa_l2_spec_E_spectra_132', 'erg_mepe_l2_omniflux_FEDO', 'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_12.0keV', 'delta_z', 'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y', 'erg_orb_l2_pos_rmlatmlt', pr_4)
# Out:
# 23-May-23 00:59:45: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 23-May-23 00:59:45: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
# ...

# %%
pr_5 = ['2017-04-12 06:00:00','2017-04-12 06:30:00']
udp1.ULF_duct_plot_12to50('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132', 'erg_pwe_ofa_l2_spec_E_spectra_132', 'erg_mepe_l2_omniflux_FEDO', 'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_12.0keV', 'delta_z', 'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y', 'erg_orb_l2_pos_rmlatmlt', pr_5)
# Out:
# 23-May-23 01:00:36: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 23-May-23 01:00:36: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
# ...

# %%
pr_6 = ['2017-04-12 06:30:00','2017-04-12 07:00:00']
udp1.ULF_duct_plot_12to50('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132', 'erg_pwe_ofa_l2_spec_E_spectra_132', 'erg_mepe_l2_omniflux_FEDO', 'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_12.0keV', 'delta_z', 'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y', 'erg_orb_l2_pos_rmlatmlt', pr_6)
# Out:
# 23-May-23 01:02:57: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 23-May-23 01:02:57: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
# ...
