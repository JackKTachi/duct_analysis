# %%
import ULF_duct_plot_detail as udp
import calc_integral_chorus as cic
import ULF_duct_plot_ver2 as udp2

download_trange = ['2017-04-14', '2017-04-15']

'ne_mgf',\
        'kvec_polar_132',\
        'erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_E_spectra_132',\
        'erg_mepe_l2_omniflux_FEDO',\
        'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_29.3keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_20.5keV','erg_mepe_l3_pa_FEDU_17.1keV','erg_mepe_l3_pa_FEDU_14.3keV','erg_mepe_l3_pa_FEDU_12.0keV',\
            'delta_z', 'erg_mgf_l2_magt_8sec','erg_mgf_l2_mag_8sec_MAF_x&y',\
            'erg_orb_l2_pos_rmlatmlt','erg_orb_l2_pos_eq' == udp2.ULF_duct_load(download_trange)
import plot_RI as pr

B = 95e-9 # T
N = 1.25e6 # m^-3
f = 1e3 # Hz
pr.plot_RI(N, B, f, 0.1, 0.1)
# Out:
# 12-Jun-23 16:25:25: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 12-Jun-23 16:25:25: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170414_v02_03.cdf
# 12-Jun-23 16:25:26: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
  

r4 = ['2017-04-14 05:00:00','2017-04-14 05:35:00']  
min = 0.1
max = 20
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r4, min, max)


theta = 0
plot_trange = r4
udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)
# Out:
# 12-Jun-23 16:25:53: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 12-Jun-23 16:25:53: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170414_v02_03.cdf
# 12-Jun-23 16:25:54: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
import pyspedas
from pyspedas.erg import pwe_hfa
pwe_hfa(trange=download_trange, mode='monit')
# Out:
# 12-Jun-23 16:30:23: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/hfa/l2/spec/monit/2017/04/
# 12-Jun-23 16:30:23: File is current: erg_data/satellite/erg/pwe/hfa/l2/spec/monit/2017/04/erg_pwe_hfa_l2_spec_monit_20170414_v01_02.cdf
# 12-Jun-23 16:30:24: erg_pwe_hfa_l2_monit_spectra_er contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 12-Jun-23 16:30:24: erg_pwe_hfa_l2_monit_spectra_el contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 12-Jun-23 16:30:24: erg_pwe_hfa_l2_monit_spectra_e_ar contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 12-Jun-23 16:30:24: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_monit_spectra_eu_ev
# ...

# %%
import pytplot
pytplot.tplot('erg_pwe_hfa_l2_monit_spectra_esum')
# Out:
# 12-Jun-23 16:30:24: No data found in the time range: erg_pwe_hfa_l2_monit_spectra_esum

# %%
import pytplot
pytplot.cdf_to_tplot('./erg_data/satellite/erg/pwe/hfa/l3/1min/2017/04/erg_pwe_hfa_l3_1min_20170414_v03_07.cdf')
# Out:
# ['Epoch', 'Fuhr', 'ne_mgf', 'quality_flag']

# %%
pytplot.tplot('ne_mgf')
# Out:
# 12-Jun-23 16:30:24: No data found in the time range: ne_mgf

# %%
import plot_RI as pr

B = 95e-9 # T
N = 2e6 # m^-3
f = 1e3 # Hz
pr.plot_RI(N, B, f, 0.5, 0.5)
# Out:
# 12-Jun-23 16:30:24: /home/jackkooki/Document/duct_analysis/basic/calc_RI.py:18: RuntimeWarning: invalid value encountered in power
#   mu = fp*(fc*f*(np.cos(theta)-(f/fc)))**(-1/2)

# %%
r4_1 = ['2017-04-14 15:30:00','2017-04-14 16:00:00']
min = 0.1
max = 1.2
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r4_1, min, max)
data_low = pytplot.data_quants['erg_pwe_ofa_l2_spec_B_chorus_integrate']
pytplot.store_data('erg_pwe_ofa_l2_spec_B_chorus_integrate_low', data={'x': data_low['time'], 'y': data_low})

min = 1.2
max = 20
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r4_1, min, max)
data_high = pytplot.data_quants['erg_pwe_ofa_l2_spec_B_chorus_integrate']
pytplot.store_data('erg_pwe_ofa_l2_spec_B_chorus_integrate_high', data={'x': data_high['time'], 'y': data_high})

pytplot.xlim(r4_1[0],r4_1[1])
pytplot.tplot(['erg_pwe_ofa_l2_spec_B_chorus_integrate_low','erg_pwe_ofa_l2_spec_B_chorus_integrate_high'])



theta = 0
plot_trange = r4_1
udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)
# Out:
# 12-Jun-23 16:30:24: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 12-Jun-23 16:30:24: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170414_v02_03.cdf
# 12-Jun-23 16:30:25: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate_high', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)
# Out:
# 12-Jun-23 16:34:33: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/8sec/2017/04/
# 12-Jun-23 16:34:33: File is current: erg_data/satellite/erg/mgf/l2/8sec/2017/04/erg_mgf_l2_8sec_20170414_v03.04.cdf
# 12-Jun-23 16:34:33: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 12-Jun-23 16:34:33: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# 12-Jun-23 16:34:33: No data found in the time range: ne_mgf
#
# ...

# %%
udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate_low', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)
# Out:
# 12-Jun-23 16:34:35: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/8sec/2017/04/
# 12-Jun-23 16:34:35: File is current: erg_data/satellite/erg/mgf/l2/8sec/2017/04/erg_mgf_l2_8sec_20170414_v03.04.cdf
# 12-Jun-23 16:34:35: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 12-Jun-23 16:34:35: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# 12-Jun-23 16:34:35: No data found in the time range: ne_mgf
#
# ...

# %%
import pyspedas
from pyspedas.erg import pwe_ofa
pwe_ofa(trange=download_trange)
pytplot.options('erg_pwe_ofa_l2_spec_B_spectra_132', opt_dict={'ylog':0, 'yrange':[0.5, 2]})

pytplot.tplot('erg_pwe_ofa_l2_spec_B_spectra_132')
# Out:
# 12-Jun-23 16:34:36: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 12-Jun-23 16:34:37: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170414_v02_03.cdf
# 12-Jun-23 16:34:37: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
pytplot.xlim(r4_1[0],r4_1[1])
pytplot.tplot(['erg_pwe_ofa_l2_spec_B_chorus_integrate_low','erg_pwe_ofa_l2_spec_B_chorus_integrate_high'])

# %%
r4_2 = ['2017-04-14 23:20:00','2017-04-15 23:50:00']
min = 0.1
max = 20
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r4_2, min, max)


theta = 0
plot_trange = r4_2
udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)
# Out:
# 12-Jun-23 16:34:38: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 12-Jun-23 16:34:38: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170414_v02_03.cdf
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# ...
