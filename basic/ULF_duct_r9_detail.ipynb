# %%
import ULF_duct_plot_detail as udp
import calc_integral_chorus as cic
import ULF_duct_plot_ver2 as udp2
import pytplot

download_trange = ['2017-04-20', '2013-04-21']

'ne_mgf',\
        'kvec_polar_132',\
        'erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_E_spectra_132',\
        'erg_mepe_l2_omniflux_FEDO',\
        'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_29.3keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_20.5keV','erg_mepe_l3_pa_FEDU_17.1keV','erg_mepe_l3_pa_FEDU_14.3keV','erg_mepe_l3_pa_FEDU_12.0keV',\
            'delta_z', 'erg_mgf_l2_magt_8sec','erg_mgf_l2_mag_8sec_MAF_x&y',\
            'erg_orb_l2_pos_rmlatmlt','erg_orb_l2_pos_eq' == udp2.ULF_duct_load(download_trange)

r9 = ['2017-04-20 02:00:00', '2017-04-20 02:30:00']
min = 0.1
max = 1.6
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r9, min, max)
low = pytplot.data_quants['erg_pwe_ofa_l2_spec_B_chorus_integrate']
pytplot.store_data('erg_pwe_ofa_l2_spec_B_chorus_integrate_low', data={'x':low['time'], 'y':low})

min = 1.61
max = 2
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r9, min, max)
high = pytplot.data_quants['erg_pwe_ofa_l2_spec_B_chorus_integrate']
pytplot.store_data('erg_pwe_ofa_l2_spec_B_chorus_integrate_high', data={'x':high['time'], 'y':high})

min = 0.1
max = 20
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r9, min, max)


""" import pytplot
import calc_stokes as cs
'erg_pwe_hfa_l2_spectra_e_mix','erg_pwe_ofa_l2_spec_E_spectra_merged', 'erg_pwe_ofa_l2_spec_B_spectra_merged', 'st_I_spec','st_V/I_spec', 'st_Q/I_spec','st_Q/I_spec_log0','st_U/I_spec','st_chi_spec', 'erg_mgf_l2_mag_64hz_sgi_x_interp', 'erg_mgf_l2_mag_64hz_sgi_y_interp', 'erg_mgf_l2_mag_64hz_sgi_z_interp' ==\
      cs.calc_stokes(download_trange, r9)

udp.plot_B_int_density('erg_pwe_ofa_l2_spec_B_spectra_132','st_Q/I_spec','erg_pwe_ofa_l2_spec_B_chorus_integrate','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',r9)

pytplot.options('erg_pwe_ofa_l2_spec_E_spectra_merged', opt_dict={'ytitle': 'E-spectra', 'ysubtitle': '[kHz]', 'ylog':0, 'yrange':[5, 20], 'zrange':[1e-2,1e-9], 'spec':1})
pytplot.tplot(['st_Q/I_spec_log0','erg_pwe_ofa_l2_spec_E_spectra_merged']) """

pytplot.options('erg_pwe_ofa_l2_spec_B_chorus_integrate_low', opt_dict={'ytitle': 'chorus_high_freq', 'ylog':1})
pytplot.options('erg_pwe_ofa_l2_spec_B_chorus_integrate_high', opt_dict={'ytitle': 'chorus_low_freq', 'ylog':1})
pytplot.options('erg_pwe_ofa_l2_spec_B_chorus_integrate', opt_dict={'ytitle': 'chorus_whole', 'ylog':1})


pytplot.xlim(r9[0], r9[1])
pytplot.tplot(['erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate_low','erg_pwe_ofa_l2_spec_B_chorus_integrate_high','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z'],xsize=10, ysize=15)


#udp.plot_B_int_z_xy('erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',r9)
# Out:
# 05-Jun-23 13:39:39: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 05-Jun-23 13:39:39: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170420_v02_03.cdf
# 05-Jun-23 13:39:40: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
r9_0 = ['2017-04-20 02:30:00', '2017-04-20 03:00:00']
min = 0.1
max = 1.1
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r9_0, min, max)
low = pytplot.data_quants['erg_pwe_ofa_l2_spec_B_chorus_integrate']
pytplot.store_data('erg_pwe_ofa_l2_spec_B_chorus_integrate_low', data={'x':low['time'], 'y':low})

min = 1.11
max = 2
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r9_0, min, max)
high = pytplot.data_quants['erg_pwe_ofa_l2_spec_B_chorus_integrate']
pytplot.store_data('erg_pwe_ofa_l2_spec_B_chorus_integrate_high', data={'x':high['time'], 'y':high})

min = 0.1
max = 20
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r9_0, min, max)


""" import pytplot
import calc_stokes as cs
'erg_pwe_hfa_l2_spectra_e_mix','erg_pwe_ofa_l2_spec_E_spectra_merged', 'erg_pwe_ofa_l2_spec_B_spectra_merged', 'st_I_spec','st_V/I_spec', 'st_Q/I_spec','st_Q/I_spec_log0','st_U/I_spec','st_chi_spec', 'erg_mgf_l2_mag_64hz_sgi_x_interp', 'erg_mgf_l2_mag_64hz_sgi_y_interp', 'erg_mgf_l2_mag_64hz_sgi_z_interp' ==\
      cs.calc_stokes(download_trange, r9_0)

udp.plot_B_int_density('erg_pwe_ofa_l2_spec_B_spectra_132','st_Q/I_spec','erg_pwe_ofa_l2_spec_B_chorus_integrate','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',r9_0)

pytplot.options('erg_pwe_ofa_l2_spec_E_spectra_merged', opt_dict={'ytitle': 'E-spectra', 'ysubtitle': '[kHz]', 'ylog':0, 'yrange':[5, 20], 'zrange':[1e-2,1e-9], 'spec':1})
pytplot.tplot(['st_Q/I_spec_log0','erg_pwe_ofa_l2_spec_E_spectra_merged']) """

pytplot.options('erg_pwe_ofa_l2_spec_B_chorus_integrate_low', opt_dict={'ytitle': 'chorus_high_freq', 'ylog':1})
pytplot.options('erg_pwe_ofa_l2_spec_B_chorus_integrate_high', opt_dict={'ytitle': 'chorus_low_freq', 'ylog':1})
pytplot.options('erg_pwe_ofa_l2_spec_B_chorus_integrate', opt_dict={'ytitle': 'chorus_integral', 'ylog':1})


pytplot.xlim(r9_0[0], r9_0[1])
pytplot.tplot(['erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate_low','erg_pwe_ofa_l2_spec_B_chorus_integrate_high','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z'],xsize=10, ysize=15)


#udp.plot_B_int_z_xy('erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',r9_0)
# Out:
# 05-Jun-23 13:55:45: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 05-Jun-23 13:55:45: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170420_v02_03.cdf
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# ...

# %%
import pyspedas
import pytplot  

download_trange = ['2017-04-20', '2013-04-21']
r9_0 = ['2017-04-20 02:30:00', '2017-04-20 03:00:00']
from pyspedas.erg import pwe_ofa
pwe_ofa(trange=download_trange)
pytplot.xlim(r9_0[0],r9_0[1])

datat = pytplot.data_quants['erg_pwe_ofa_l2_spec_B_spectra_132']

pytplot.store_data('erg_pwe_ofa_l2_spec_B_spectra_132', data={'x': datat['time'], 'y': datat, 'v': datat['spec_bins']})
pytplot.options('erg_pwe_ofa_l2_spec_B_spectra_132', opt_dict={'ytitle': 'B-spectra', 'ysubtitle': '[kHz]', 'ylog':1, 'yrange':[0.064, 0.704],'spec':1, 'zlog':1,'zrange':[1e2,1e-4]})
pytplot.ylim('erg_pwe_ofa_l2_spec_B_spectra_132', 0.064, 1)
pytplot.tplot(['erg_pwe_ofa_l2_spec_B_spectra_132'])
# Out:
# 05-Jun-23 13:55:28: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 05-Jun-23 13:55:28: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170420_v02_03.cdf
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
