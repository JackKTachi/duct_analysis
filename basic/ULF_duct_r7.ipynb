# %%
import ULF_duct_plot_detail as udp
import calc_integral_chorus as cic
import ULF_duct_plot_ver2 as udp2

download_trange = ['2017-04-14', '2017-04-15']

'ne_mgf',\
        'kvec_polar_132',\
        'erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_E_spectra_132',\
        'erg_mepe_l2_omniflux_FEDO',\
        'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_29.3keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_20.5keV','erg_mepe_l3_pa_FEDU_17.1keV','erg_mepe_l3_pa_FEDU_14.3keV','erg_mepe_l3_pa_FEDU_12.0keV',\
            'delta_z', 'erg_mgf_l2_magt_8sec','erg_mgf_l2_mag_8sec_MAF_x&y',\
            'erg_orb_l2_pos_rmlatmlt','erg_orb_l2_pos_eq' == udp2.ULF_duct_load(download_trange)
r7 = ['2017-04-14 23:30:00', '2017-04-14 23:55:00']
min = 0.1
max = 2
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r7, min, max)


import pytplot
import calc_stokes as cs
'erg_pwe_hfa_l2_spectra_e_mix','erg_pwe_ofa_l2_spec_E_spectra_merged', 'erg_pwe_ofa_l2_spec_B_spectra_merged', 'st_I_spec','st_V/I_spec', 'st_Q/I_spec','st_Q/I_spec_log0','st_U/I_spec','st_chi_spec', 'erg_mgf_l2_mag_64hz_sgi_x_interp', 'erg_mgf_l2_mag_64hz_sgi_y_interp', 'erg_mgf_l2_mag_64hz_sgi_z_interp' ==\
      cs.calc_stokes(download_trange, r7)

udp.plot_B_int_density('erg_pwe_ofa_l2_spec_B_spectra_132','st_Q/I_spec','erg_pwe_ofa_l2_spec_B_chorus_integrate','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',r7)

pytplot.options('erg_pwe_ofa_l2_spec_E_spectra_merged', opt_dict={'ytitle': 'E-spectra', 'ysubtitle': '[kHz]', 'ylog':0, 'yrange':[5, 20], 'zrange':[1e-2,1e-9], 'spec':1})
pytplot.tplot(['st_Q/I_spec_log0','erg_pwe_ofa_l2_spec_E_spectra_merged'])


#udp.plot_B_int_z_xy('erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',r7)
# Out:
# 04-Jun-23 20:29:30: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 04-Jun-23 20:29:30: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170414_v02_03.cdf
# 04-Jun-23 20:29:31: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jun-23 20:29:32: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/8sec/2017/04/
# 04-Jun-23 20:29:32: File is current: erg_data/satellite/erg/mgf/l2/8sec/2017/04/erg_mgf_l2_8sec_20170414_v03.04.cdf
# 04-Jun-23 20:29:32: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2017/
# 04-Jun-23 20:29:32: File is current: erg_data/satellite/erg/orb/def/2017/erg_orb_l2_20170414_v03.cdf
# 04-Jun-23 20:29:32: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Magnetic Field Experiment (MGF) Level 2 spin-averaged magnetic field data
#
# Information about ERG MGF
#
# PI:  Ayako Matsuoka
# Affiliation: Data Analysis Center for Geomagnetism and Space Magnetism, Graduate School of Science, Kyoto University, Kitashirakawa-Oiwake Cho, Sakyo-ku Kyoto 606-8502, Japan
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of MGF L2: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Mgf
# Contact: erg_mgf_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jun-23 20:29:32: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jun-23 20:29:44: /home/jackkooki/Document/duct_analysis/basic/compressional_B.py:40: RuntimeWarning: invalid value encountered in divide
#   cos_th = data_200s_z/ data_200s_total
#
# 04-Jun-23 20:29:44: /home/jackkooki/Document/duct_analysis/basic/compressional_B.py:41: RuntimeWarning: invalid value encountered in divide
#   sin_th = np.sqrt(data_200s_x**2 + data_200s_y**2) / data_200s_total
#
# 04-Jun-23 20:29:44: /home/jackkooki/Document/duct_analysis/basic/compressional_B.py:43: RuntimeWarning: invalid value encountered in divide
#   cos_ph = data_200s_x/ np.sqrt(data_200s_x**2 + data_200s_y**2)
#
# 04-Jun-23 20:29:44: /home/jackkooki/Document/duct_analysis/basic/compressional_B.py:44: RuntimeWarning: invalid value encountered in divide
#   sin_ph = data_200s_y / np.sqrt(data_200s_x**2 + data_200s_y**2)
#
# 04-Jun-23 20:29:44: tinterpol (linear) was applied to: cos_th_intpl
# 04-Jun-23 20:29:44: tinterpol (linear) was applied to: sin_th_intpl
# 04-Jun-23 20:29:44: tinterpol (linear) was applied to: cos_ph_intpl
# 04-Jun-23 20:29:44: tinterpol (linear) was applied to: sin_ph_intpl
# 04-Jun-23 20:29:44: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_x_intpl
# 04-Jun-23 20:29:44: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_y_intpl
# 04-Jun-23 20:29:44: tinterpol (linear) was applied to: erg_mgf_l2_mag_8sec_gsm_z_intpl
# 04-Jun-23 20:29:58: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mepe/l2/omniflux/2017/04/
# 04-Jun-23 20:29:59: File is current: erg_data/satellite/erg/mepe/l2/omniflux/2017/04/erg_mepe_l2_omniflux_20170414_v01_02.cdf
# 04-Jun-23 20:29:59: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 04-Jun-23 20:29:59: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2017/
# 04-Jun-23 20:29:59: File is current: erg_data/satellite/erg/orb/def/2017/erg_orb_l2_20170414_v03.cdf
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Medium Energy Particle experiments - electron analyzer (MEP-e) electron omni flux data
#
# PI:  Satoshi Kasahara
# Affiliation: The University of Tokyo
#
# - The rules of the road (RoR) common to the ERG project:
#       https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# - RoR for MEP-e data:  https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Mepe
#
# Contact: erg_mep_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jun-23 20:29:59: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 04-Jun-23 20:29:59: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170414_v02_03.cdf
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jun-23 20:30:00: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jun-23 20:31:07: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/8sec/2017/04/
# 04-Jun-23 20:31:07: File is current: erg_data/satellite/erg/mgf/l2/8sec/2017/04/erg_mgf_l2_8sec_20170414_v03.04.cdf
# 04-Jun-23 20:31:07: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 04-Jun-23 20:31:07: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# 04-Jun-23 20:31:07: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/64hz/2017/04/
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Magnetic Field Experiment (MGF) Level 2 spin-averaged magnetic field data
#
# Information about ERG MGF
#
# PI:  Ayako Matsuoka
# Affiliation: Data Analysis Center for Geomagnetism and Space Magnetism, Graduate School of Science, Kyoto University, Kitashirakawa-Oiwake Cho, Sakyo-ku Kyoto 606-8502, Japan
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of MGF L2: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Mgf
# Contact: erg_mgf_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jun-23 20:31:09: Downloading https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/64hz/2017/04/erg_mgf_l2_64hz_sgi_2017041423_v03.04.cdf to erg_data/satellite/erg/mgf/l2/64hz/2017/04/erg_mgf_l2_64hz_sgi_2017041423_v03.04.cdf
# 04-Jun-23 20:31:10: Download complete: erg_data/satellite/erg/mgf/l2/64hz/2017/04/erg_mgf_l2_64hz_sgi_2017041423_v03.04.cdf
# 04-Jun-23 20:31:11: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# 04-Jun-23 20:31:11: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 04-Jun-23 20:31:11: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Magnetic Field Experiment (MGF) Level 2 64 Hz resolution magnetic field data
#
# Information about ERG MGF
#
# PI:  Ayako Matsuoka
# Affiliation: Data Analysis Center for Geomagnetism and Space Magnetism, Graduate School of Science, Kyoto University, Kitashirakawa-Oiwake Cho, Sakyo-ku Kyoto 606-8502, Japan
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of MGF L2: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Mgf
# Contact: erg_mgf_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jun-23 20:31:11: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170414_v02_03.cdf
# 04-Jun-23 20:31:12: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jun-23 20:31:13: Conflicting size for at least one dimension for variable Ex_Ex_132
# 04-Jun-23 20:31:13: Could not create coordinate v1_dim for variable Ex_Ex_132
# 04-Jun-23 20:31:13: Could not create coordinate v2_dim for variable Ex_Ex_132
# 04-Jun-23 20:31:13: Ex_Ex_132 does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:13: Conflicting size for at least one dimension for variable Ey_Ey_132
# 04-Jun-23 20:31:13: Could not create coordinate v1_dim for variable Ey_Ey_132
# 04-Jun-23 20:31:13: Could not create coordinate v2_dim for variable Ey_Ey_132
# 04-Jun-23 20:31:13: Ey_Ey_132 does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:13: Conflicting size for at least one dimension for variable Ex_Ey_132
# 04-Jun-23 20:31:13: Could not create coordinate v1_dim for variable Ex_Ey_132
# 04-Jun-23 20:31:13: Could not create coordinate v2_dim for variable Ex_Ey_132
# 04-Jun-23 20:31:13: Ex_Ey_132 does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:13: Conflicting size for at least one dimension for variable Ey_Ex_132
# 04-Jun-23 20:31:13: Could not create coordinate v1_dim for variable Ey_Ex_132
# 04-Jun-23 20:31:13: Could not create coordinate v2_dim for variable Ey_Ex_132
# 04-Jun-23 20:31:13: Ey_Ex_132 does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:13: Conflicting size for at least one dimension for variable Bx_Bx_132
# 04-Jun-23 20:31:13: Could not create coordinate v1_dim for variable Bx_Bx_132
# 04-Jun-23 20:31:13: Could not create coordinate v2_dim for variable Bx_Bx_132
# 04-Jun-23 20:31:13: Bx_Bx_132 does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:13: Conflicting size for at least one dimension for variable By_By_132
# 04-Jun-23 20:31:13: Could not create coordinate v1_dim for variable By_By_132
# 04-Jun-23 20:31:13: Could not create coordinate v2_dim for variable By_By_132
# 04-Jun-23 20:31:13: By_By_132 does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:13: Conflicting size for at least one dimension for variable Bz_Bz_132
# 04-Jun-23 20:31:13: Could not create coordinate v1_dim for variable Bz_Bz_132
# 04-Jun-23 20:31:13: Could not create coordinate v2_dim for variable Bz_Bz_132
# 04-Jun-23 20:31:13: Bz_Bz_132 does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:13: Conflicting size for at least one dimension for variable Bx_By_132
# 04-Jun-23 20:31:13: Could not create coordinate v1_dim for variable Bx_By_132
# 04-Jun-23 20:31:13: Could not create coordinate v2_dim for variable Bx_By_132
# 04-Jun-23 20:31:13: Bx_By_132 does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:13: Conflicting size for at least one dimension for variable Bx_Bz_132
# 04-Jun-23 20:31:13: Could not create coordinate v1_dim for variable Bx_Bz_132
# 04-Jun-23 20:31:13: Could not create coordinate v2_dim for variable Bx_Bz_132
# 04-Jun-23 20:31:13: Bx_Bz_132 does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:13: Conflicting size for at least one dimension for variable By_Bx_132
# 04-Jun-23 20:31:13: Could not create coordinate v1_dim for variable By_Bx_132
# 04-Jun-23 20:31:13: Could not create coordinate v2_dim for variable By_Bx_132
# 04-Jun-23 20:31:13: By_Bx_132 does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:13: Conflicting size for at least one dimension for variable By_Bz_132
# 04-Jun-23 20:31:13: Could not create coordinate v1_dim for variable By_Bz_132
# 04-Jun-23 20:31:13: Could not create coordinate v2_dim for variable By_Bz_132
# 04-Jun-23 20:31:13: By_Bz_132 does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:13: Conflicting size for at least one dimension for variable Bz_Bx_132
# 04-Jun-23 20:31:13: Could not create coordinate v1_dim for variable Bz_Bx_132
# 04-Jun-23 20:31:13: Could not create coordinate v2_dim for variable Bz_Bx_132
# 04-Jun-23 20:31:13: Bz_Bx_132 does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:13: Conflicting size for at least one dimension for variable Bz_By_132
# 04-Jun-23 20:31:13: Could not create coordinate v1_dim for variable Bz_By_132
# 04-Jun-23 20:31:13: Could not create coordinate v2_dim for variable Bz_By_132
# 04-Jun-23 20:31:13: Bz_By_132 does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:14: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/hfa/l2/spec/low/2017/04/
# 04-Jun-23 20:31:14: File is current: erg_data/satellite/erg/pwe/hfa/l2/spec/low/2017/04/erg_pwe_hfa_l2_spec_low_20170414_v01_02.cdf
# 04-Jun-23 20:31:14: erg_pwe_hfa_l2_low_spectra_er contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 04-Jun-23 20:31:14: erg_pwe_hfa_l2_low_spectra_el contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 04-Jun-23 20:31:14: erg_pwe_hfa_l2_low_spectra_e_ar contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 04-Jun-23 20:31:14: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# 04-Jun-23 20:31:14: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# 04-Jun-23 20:31:14: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# 04-Jun-23 20:31:14: erg_pwe_hfa_l2_low_spectra_eu_ev does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:14: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_low_spectra_eu_bg
# 04-Jun-23 20:31:14: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_low_spectra_eu_bg
# 04-Jun-23 20:31:14: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_low_spectra_eu_bg
# 04-Jun-23 20:31:14: erg_pwe_hfa_l2_low_spectra_eu_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:14: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_low_spectra_ev_bg
# 04-Jun-23 20:31:14: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_low_spectra_ev_bg
# 04-Jun-23 20:31:14: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_low_spectra_ev_bg
# 04-Jun-23 20:31:14: erg_pwe_hfa_l2_low_spectra_ev_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:15: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/hfa/l2/spec/high/2017/04/
# 04-Jun-23 20:31:15: File is current: erg_data/satellite/erg/pwe/hfa/l2/spec/high/2017/04/erg_pwe_hfa_l2_spec_high_20170414_v01_02.cdf
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Electric Field Data (HFA) Level 2 spectrum data
#
# Information about ERG PWE HFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/HFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Hfa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jun-23 20:31:17: erg_pwe_hfa_l2_high_spectra_eu contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 04-Jun-23 20:31:18: erg_pwe_hfa_l2_high_spectra_ev contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 04-Jun-23 20:31:18: erg_pwe_hfa_l2_high_spectra_er contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 04-Jun-23 20:31:18: erg_pwe_hfa_l2_high_spectra_el contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 04-Jun-23 20:31:18: erg_pwe_hfa_l2_high_spectra_e_mix contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 04-Jun-23 20:31:18: erg_pwe_hfa_l2_high_spectra_e_ar contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 04-Jun-23 20:31:18: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_high_spectra_eu_ev
# 04-Jun-23 20:31:18: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_high_spectra_eu_ev
# 04-Jun-23 20:31:18: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_high_spectra_eu_ev
# 04-Jun-23 20:31:18: erg_pwe_hfa_l2_high_spectra_eu_ev does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:18: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_high_spectra_eu_bg
# 04-Jun-23 20:31:18: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_high_spectra_eu_bg
# 04-Jun-23 20:31:18: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_high_spectra_eu_bg
# 04-Jun-23 20:31:18: erg_pwe_hfa_l2_high_spectra_eu_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 04-Jun-23 20:31:18: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_high_spectra_ev_bg
# 04-Jun-23 20:31:18: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_high_spectra_ev_bg
# 04-Jun-23 20:31:18: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_high_spectra_ev_bg
# 04-Jun-23 20:31:18: erg_pwe_hfa_l2_high_spectra_ev_bg does not contain coordinates for spectrogram plotting.  Continuing...
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Electric Field Data (HFA) Level 2 spectrum data
#
# Information about ERG PWE HFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/HFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Hfa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 04-Jun-23 20:31:20: tinterpol (linear) was applied to: erg_mgf_l2_mag_64hz_sgi_x_interp
# 04-Jun-23 20:31:20: tinterpol (linear) was applied to: erg_mgf_l2_mag_64hz_sgi_y_interp
# 04-Jun-23 20:31:20: tinterpol (linear) was applied to: erg_mgf_l2_mag_64hz_sgi_z_interp
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
#
# 04-Jun-23 20:31:39: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   out_ticks.append('{:.2f}'.format(var_xr.interp(coords={'time': time}, kwargs={'fill_value': 'extrapolate', 'bounds_error': False}).values))
