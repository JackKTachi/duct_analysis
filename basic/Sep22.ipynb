# %%
import ULF_duct_plot_detail as ulf

dtr =  ['2017-09-22', '2017-09-23']

'kvec_polar_132',\
        'erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_E_spectra_132',\
            'delta_z', 'erg_mgf_l2_magt_8sec','erg_mgf_l2_mag_8sec_MAF_x&y',\
            'erg_orb_l2_pos_rmlatmlt','erg_orb_l2_pos_eq' == ulf.ULF_evensearch_load(dtr)





tr1 = ['2017-09-22 00:30:00', '2017-09-22 01:00:00']
ulf.ULF_eventsearch_plot('kvec_polar_132',\
        'erg_pwe_ofa_l2_spec_B_spectra_132','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y', 'erg_mgf_l2_magt_8sec',\
            'erg_orb_l2_pos_rmlatmlt',tr1)
# Out:
# 17-Jun-23 15:11:06: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/09/
# 17-Jun-23 15:11:07: Downloading https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/09/erg_pwe_ofa_l2_spec_20170922_v02_03.cdf to erg_data/satellite/erg/pwe/ofa/l2/spec/2017/09/erg_pwe_ofa_l2_spec_20170922_v02_03.cdf
# 17-Jun-23 15:11:16: Download complete: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/09/erg_pwe_ofa_l2_spec_20170922_v02_03.cdf
# 17-Jun-23 15:11:17: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# ...
