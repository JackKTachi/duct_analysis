# %%
import ULF_duct_plot_detail as udp
import calc_integral_chorus as cic
import ULF_duct_plot_ver2 as udp2

download_trange = ['2017-04-24', '2013-04-25']
'ne_mgf',\
        'kvec_polar_132',\
        'erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_E_spectra_132',\
        'erg_mepe_l2_omniflux_FEDO',\
        'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_29.3keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_20.5keV','erg_mepe_l3_pa_FEDU_17.1keV','erg_mepe_l3_pa_FEDU_14.3keV','erg_mepe_l3_pa_FEDU_12.0keV',\
            'delta_z', 'erg_mgf_l2_magt_8sec','erg_mgf_l2_mag_8sec_MAF_x&y',\
            'erg_orb_l2_pos_rmlatmlt','erg_orb_l2_pos_eq' == udp2.ULF_duct_load(download_trange)
""" 
r13 = ['2017-04-24 04:30:00', '2017-04-24 05:30:00']
min = 0.1
max = 2
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r13, min, max)


f = 0.7
theta = 0
plot_trange = r13
udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)




import pytplot
import calc_stokes as cs
'erg_pwe_hfa_l2_spectra_e_mix','erg_pwe_ofa_l2_spec_E_spectra_merged', 'erg_pwe_ofa_l2_spec_B_spectra_merged', 'st_I_spec','st_V/I_spec', 'st_Q/I_spec','st_Q/I_spec_log0','st_U/I_spec','st_chi_spec', 'erg_mgf_l2_mag_64hz_sgi_x_interp', 'erg_mgf_l2_mag_64hz_sgi_y_interp', 'erg_mgf_l2_mag_64hz_sgi_z_interp' ==\
      cs.calc_stokes(download_trange, r13)

udp.plot_B_int_density('erg_pwe_ofa_l2_spec_B_spectra_132','st_Q/I_spec','erg_pwe_ofa_l2_spec_B_chorus_integrate','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',r13)

pytplot.options('erg_pwe_ofa_l2_spec_E_spectra_merged', opt_dict={'ytitle': 'E-spectra', 'ysubtitle': '[kHz]', 'ylog':0, 'yrange':[5, 20], 'zrange':[1e-2,1e-9], 'spec':1})
pytplot.tplot(['st_Q/I_spec_log0','erg_pwe_ofa_l2_spec_E_spectra_merged'])

udp.plot_B_int_z_xy('erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',r13)
 """
# Out:
# 17-Jun-23 16:54:35: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 17-Jun-23 16:54:35: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170424_v02_03.cdf
# 17-Jun-23 16:54:36: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
tr1 = ['2017-04-24 04:30:00', '2017-04-24 05:30:00']
udp.ULF_eventsearch_plot('kvec_polar_132',\
        'erg_pwe_ofa_l2_spec_B_spectra_132','delta_z','erg_mgf_l2_mag_8sec_MAF_x&y', 'erg_mgf_l2_magt_8sec',\
            'erg_orb_l2_pos_rmlatmlt',tr1)
# Out:
# 17-Jun-23 16:55:00: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:423: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   xaxis_ticks_dt = [np.datetime64(mpl.dates.num2date(tick_val).isoformat()) for tick_val in xaxis_ticks]
#
# 17-Jun-23 16:55:00: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/MPLPlotter/tplot.py:618: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
# ...

# %%
from pyspedas.erg import pwe_hfa
pwe_hfa(trange=download_trange, mode='low')
# Out:
# 08-Jun-23 20:55:36: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/hfa/l2/spec/low/2017/04/
# 08-Jun-23 20:55:36: File is current: erg_data/satellite/erg/pwe/hfa/l2/spec/low/2017/04/erg_pwe_hfa_l2_spec_low_20170424_v01_02.cdf
# 08-Jun-23 20:55:37: erg_pwe_hfa_l2_low_spectra_er contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 08-Jun-23 20:55:37: erg_pwe_hfa_l2_low_spectra_el contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 08-Jun-23 20:55:37: erg_pwe_hfa_l2_low_spectra_e_ar contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 08-Jun-23 20:55:37: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# 08-Jun-23 20:55:37: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# ...

# %%
pytplot.options('erg_pwe_hfa_l2_low_spectra_esum', opt_dict={'ytitle': 'E-spectra', 'ysubtitle': '[kHz]', 'ylog':0, 'yrange':[5, 20], 'zrange':[1e-9,1e-4], 'spec':1})
pytplot.ylim('erg_pwe_hfa_l2_low_spectra_esum', 5, 20)
pytplot.tplot('erg_pwe_hfa_l2_low_spectra_esum')

# %%
import pyspedas
import pytplot
import numpy as np
max = 17
r1 = r13
import datetime
# 元の時間配列
time_array = pytplot.data_quants['erg_pwe_hfa_l2_low_spectra_esum']['time']

# 指定された範囲
r1_start = datetime.datetime.strptime(r1[0], '%Y-%m-%d %H:%M:%S')
r1_end = datetime.datetime.strptime(r1[1], '%Y-%m-%d %H:%M:%S')

# 始まりのインデックスを取得
start_index = -1
for i, timestamp in enumerate(time_array):
    if timestamp >= np.datetime64(r1_start):
        start_index = i
        break
# 終わりのインデックスを取得
end_index = -1
for i in range(len(time_array) - 1, -1, -1):
    timestamp = time_array[i]
    if timestamp <= np.datetime64(r1_end):
        end_index = i
        break    

def find_max_index_below_threshold(coords, threshold):
    max_index = -1

    for index, value in enumerate(coords['spec_bins']):
        if value <= threshold:
            
            max_index = index

    return max_index

max_index = find_max_index_below_threshold(pytplot.data_quants['erg_pwe_hfa_l2_low_spectra_esum'], max)



data = np.zeros(len(pytplot.data_quants['erg_pwe_hfa_l2_low_spectra_esum']['time']))

data1 = pytplot.data_quants['erg_pwe_hfa_l2_low_spectra_esum']['spec_bins']
reverse_data1 = data1[::-1]

for i in range(start_index, end_index + 1):
    for j in range(max_index, -1, -1):
        if pytplot.data_quants['erg_pwe_hfa_l2_low_spectra_esum'][i][j] > 5e-8:
            data[i] = data1[j]
            break
    else:
        data[i] = 0
for i in range(data.size):
    if data[i] < 3.75:
        data[i] = np.nan
pytplot.options('erg_pwe_ofa_l2_spec_E_spectra_132', opt_dict={'ytitle': 'E-spectra', 'ysubtitle': '[kHz]', 'ylog':0, 'yrange':[5, 15], 'spec':1})
pytplot.store_data('plasma_frequency', data={'x': pytplot.data_quants['erg_pwe_hfa_l2_low_spectra_esum']['time'], 'y': data})
pytplot.options('plasma_frequency', opt_dict={'ytitle': 'plasma frequency', 'ysubtitle': '[kHz]', 'ylog':0, 'yrange':[5, 15], 'thick':1})
pytplot.store_data('merged', data=['erg_pwe_ofa_l2_spec_E_spectra_132','plasma_frequency'])
pytplot.options('plasma_frequency', opt_dict={'ytitle': 'plasma frequency', 'ysubtitle': '[kHz]', 'ylog':0, 'thick':1})
pytplot.store_data('mergedQ/I', data=[ 'st_Q/I_spec','plasma_frequency'])
pytplot.tplot(['st_Q/I_spec_log0','plasma_frequency','merged','mergedQ/I'],xsize=10, ysize=10)

# %%
pytplot.tplot('merged')

# %%
# below 6.5kHz

import pyspedas
import pytplot
import numpy as np
max = 5.5
from pyspedas.erg import pwe_ofa
pwe_ofa(trange=download_trange)
r1 = r13
import datetime
# 元の時間配列
time_array = pytplot.data_quants['st_Q/I_spec']['time']

# 指定された範囲
r1_start = datetime.datetime.strptime(r1[0], '%Y-%m-%d %H:%M:%S')
r1_end = datetime.datetime.strptime(r1[1], '%Y-%m-%d %H:%M:%S')

# 始まりのインデックスを取得
start_index = -1
for i, timestamp in enumerate(time_array):
    if timestamp >= np.datetime64(r1_start):
        start_index = i
        break
# 終わりのインデックスを取得
end_index = -1
for i in range(len(time_array) - 1, -1, -1):
    timestamp = time_array[i]
    if timestamp <= np.datetime64(r1_end):
        end_index = i
        break    

def find_max_index_below_threshold(coords, threshold):
    max_index = -1

    for index, value in enumerate(coords['spec_bins']):
        if value <= threshold:
            
            max_index = index

    return max_index

max_index = find_max_index_below_threshold(pytplot.data_quants['erg_pwe_ofa_l2_spec_B_spectra_132'], max)



data = np.zeros(len(pytplot.data_quants['st_Q/I_spec']['time']))

data1 = pytplot.data_quants['erg_pwe_ofa_l2_spec_B_spectra_132']['spec_bins']
reverse_data1 = data1[::-1]

for i in range(start_index, end_index + 1):
    for j in range(max_index, -1, -1):
        if pytplot.data_quants['st_Q/I_spec'][i][j] < -0.90:
            data[i] = data1[j]
            break
    else:
        data[i] = 0
for i in range(data.size):
    if data[i] < 3.75:
        data[i] = np.nan
pytplot.options('erg_pwe_ofa_l2_spec_E_spectra_132', opt_dict={'ytitle': 'E-spectra', 'ysubtitle': '[kHz]', 'ylog':0, 'yrange':[2, 7], 'spec':1})
pytplot.store_data('plasma_frequency', data={'x': pytplot.data_quants['st_Q/I_spec']['time'], 'y': data})
pytplot.options('plasma_frequency', opt_dict={'ytitle': 'plasma frequency', 'ysubtitle': '[kHz]', 'ylog':0, 'yrange':[2, 7], 'thick':1})
pytplot.store_data('merged', data=['erg_pwe_ofa_l2_spec_E_spectra_132','plasma_frequency'])
pytplot.options('plasma_frequency', opt_dict={'ytitle': 'plasma frequency', 'ysubtitle': '[kHz]', 'ylog':0, 'thick':1})
pytplot.store_data('mergedQ/I', data=[ 'st_Q/I_spec','plasma_frequency'])
pytplot.tplot(['st_Q/I_spec_log0','plasma_frequency','merged','mergedQ/I'],xsize=10, ysize=10)
# Out:
# 08-Jun-23 21:20:50: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 08-Jun-23 21:20:50: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170424_v02_03.cdf
# 08-Jun-23 21:20:50: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
import ULF_duct_plot_detail as udp
import calc_integral_chorus as cic
import ULF_duct_plot_ver2 as udp2

download_trange = ['2017-04-24', '2013-04-25']
'ne_mgf',\
        'kvec_polar_132',\
        'erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_E_spectra_132',\
        'erg_mepe_l2_omniflux_FEDO',\
        'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_29.3keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_20.5keV','erg_mepe_l3_pa_FEDU_17.1keV','erg_mepe_l3_pa_FEDU_14.3keV','erg_mepe_l3_pa_FEDU_12.0keV',\
            'delta_z', 'erg_mgf_l2_magt_8sec','erg_mgf_l2_mag_8sec_MAF_x&y',\
            'erg_orb_l2_pos_rmlatmlt','erg_orb_l2_pos_eq' == udp2.ULF_duct_load(download_trange)

r13_0 = ['2017-04-24 04:35:00', '2017-04-24 05:05:00']
min = 0.1
max = 2
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r13_0, min, max)


f = 0.7
theta = 0
plot_trange = r13_0
udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)
# Out:
# 06-Jun-23 19:08:11: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
# 06-Jun-23 19:08:11: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170424_v02_03.cdf
# 06-Jun-23 19:08:12: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...
