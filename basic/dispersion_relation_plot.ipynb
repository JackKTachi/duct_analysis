# %%
import calc_dispersion_relation as cdr
import matplotlib.pyplot as plt
import numpy as np

f = np.linspace(1, 100000, 100000)

theta = 0
n_L_0, n_R_0, S_0, D_0, P_0 = cdr.calc_squared_refractive_index(f, theta)

theta = 10
n_L_10, n_R_10, S_10, D_10, P_10 = cdr.calc_squared_refractive_index(f, theta)

theta = 20
n_L_20, n_R_20, S_20, D_20, P_20 = cdr.calc_squared_refractive_index(f, theta)

theta = 30
n_L_30, n_R_30, S_30, D_30, P_30 = cdr.calc_squared_refractive_index(f, theta)

theta = 40
n_L_40, n_R_40, S_40, D_40, P_40 = cdr.calc_squared_refractive_index(f, theta)

theta = 50
n_L_50, n_R_50, S_50, D_50, P_50 = cdr.calc_squared_refractive_index(f, theta)

theta = 60
n_L_60, n_R_60, S_60, D_60, P_60 = cdr.calc_squared_refractive_index(f, theta)

theta = 70
n_L_70, n_R_70, S_70, D_70, P_70 = cdr.calc_squared_refractive_index(f, theta)

theta = 80
n_L_80, n_R_80, S_80, D_80, P_80 = cdr.calc_squared_refractive_index(f, theta)

theta = 90
n_L_90, n_R_90, S_90, D_90, P_90 = cdr.calc_squared_refractive_index(f, theta)

# %%
import plasma_params as pp
pp.omega_e['value']
# Out:
# -85439.56043956045

# %%
fig, ax = plt.subplots()
ax.plot(f, n_L_0, label='Lrot_0deg')
ax.plot(f, n_L_10, label='Lrot_10deg')
ax.plot(f, n_L_20, label='Lrot_20deg')
ax.plot(f, n_L_30, label='Lrot_30deg')
ax.plot(f, n_L_40, label='Lrot_40deg')
ax.plot(f, n_L_50, label='Lrot_50deg')
ax.plot(f, n_L_60, label='Lrot_60deg')
ax.plot(f, n_L_70, label='Lrot_70deg')
ax.plot(f, n_L_80, label='Lrot_80deg')
ax.plot(f, n_L_90, label='Lrot_90deg')

ax.plot(f, n_R_0, label='Rrot_0deg')
ax.plot(f, n_R_10, label='Rrot_10deg')
ax.plot(f, n_R_20, label='Rrot_20deg')
ax.plot(f, n_R_30, label='Rrot_30deg')
ax.plot(f, n_R_40, label='Rrot_40deg')
ax.plot(f, n_R_50, label='Rrot_50deg')
ax.plot(f, n_R_60, label='Rrot_60deg')
ax.plot(f, n_R_70, label='Rrot_70deg')
ax.plot(f, n_R_80, label='Rrot_80deg')
ax.plot(f, n_R_90, label='Rrot_90deg')

ax.set_xlabel('frequency [Hz]')
ax.set_ylabel('square of refractive index')
ax.set_title('square of refractive index vs frequency')
ax.legend()
plt.legend(loc='upper right')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(f, n_L_0, label='Lrot_0deg')
ax.plot(f, n_L_10, label='Lrot_10deg')
ax.plot(f, n_L_20, label='Lrot_20deg')
ax.plot(f, n_L_30, label='Lrot_30deg')
ax.plot(f, n_L_40, label='Lrot_40deg')
ax.plot(f, n_L_50, label='Lrot_50deg')
ax.plot(f, n_L_60, label='Lrot_60deg')
ax.plot(f, n_L_70, label='Lrot_70deg')
ax.plot(f, n_L_80, label='Lrot_80deg')

ax.plot(f, n_R_0, label='Rrot_0deg')
ax.plot(f, n_R_10, label='Rrot_10deg')
ax.plot(f, n_R_20, label='Rrot_20deg')
ax.plot(f, n_R_30, label='Rrot_30deg')
ax.plot(f, n_R_40, label='Rrot_40deg')
ax.plot(f, n_R_50, label='Rrot_50deg')
ax.plot(f, n_R_60, label='Rrot_60deg')
ax.plot(f, n_R_70, label='Rrot_70deg')
ax.plot(f, n_R_80, label='Rrot_80deg')

ax.set_xlabel('frequency [Hz]')
ax.set_ylabel('square of refractive index')
ax.set_title('square of refractive index vs frequency')
ax.legend()
plt.ylim(0, 0.4e7)
plt.xlim(6e5, 6.5e5)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# イオンサイクロトロン共鳴

# %%
import calc_dispersion_relation as cdr

norm_w, norm_n_L_0 = cdr.norm_squared_refractive_index(f, n_L_0)
norm_w, norm_n_L_10 = cdr.norm_squared_refractive_index(f, n_L_10)
norm_w, norm_n_L_20 = cdr.norm_squared_refractive_index(f, n_L_20)
norm_w, norm_n_L_30 = cdr.norm_squared_refractive_index(f, n_L_30)
norm_w, norm_n_L_40 = cdr.norm_squared_refractive_index(f, n_L_40)
norm_w, norm_n_L_50 = cdr.norm_squared_refractive_index(f, n_L_50)
norm_w, norm_n_L_60 = cdr.norm_squared_refractive_index(f, n_L_60)
norm_w, norm_n_L_70 = cdr.norm_squared_refractive_index(f, n_L_70)
norm_w, norm_n_L_80 = cdr.norm_squared_refractive_index(f, n_L_80)
norm_w, norm_n_R_0 = cdr.norm_squared_refractive_index(f, n_R_0)
norm_w, norm_n_R_10 = cdr.norm_squared_refractive_index(f, n_R_10)
norm_w, norm_n_R_20 = cdr.norm_squared_refractive_index(f, n_R_20)
norm_w, norm_n_R_30 = cdr.norm_squared_refractive_index(f, n_R_30)
norm_w, norm_n_R_40 = cdr.norm_squared_refractive_index(f, n_R_40)
norm_w, norm_n_R_50 = cdr.norm_squared_refractive_index(f, n_R_50)
norm_w, norm_n_R_60 = cdr.norm_squared_refractive_index(f, n_R_60)
norm_w, norm_n_R_70 = cdr.norm_squared_refractive_index(f, n_R_70)
norm_w, norm_n_R_80 = cdr.norm_squared_refractive_index(f, n_R_80)

# %%
pp.omega_e
# Out:
# {'value': -85439.56043956045, 'label': '$\\Omega_{ce}$'}

# %%
pp.wuh
# Out:
# {'value': 641788.9669801474, 'label': '$\\Omega_{uh}$'}

# %%
pp.wuh['value']/np.abs(pp.omega_e['value'])
# Out:
# 7.5116136328223035

# %%
fig, ax = plt.subplots()
ax.plot(norm_w, norm_n_L_0, label='Lrot_0deg')
ax.plot(norm_w, norm_n_L_10, label='Lrot_10deg')
ax.plot(norm_w, norm_n_L_20, label='Lrot_20deg')
ax.plot(norm_w, norm_n_L_30, label='Lrot_30deg')
""" ax.plot(norm_w, norm_n_L_40, label='Lrot_40deg')
ax.plot(norm_w, norm_n_L_50, label='Lrot_50deg')
ax.plot(norm_w, norm_n_L_60, label='Lrot_60deg')
ax.plot(norm_w, norm_n_L_70, label='Lrot_70deg')
ax.plot(norm_w, norm_n_L_80, label='Lrot_80deg') """
ax.plot(norm_w, norm_n_R_0, label='Rrot_0deg')
ax.plot(norm_w, norm_n_R_10, label='Rrot_10deg')
ax.plot(norm_w, norm_n_R_20, label='Rrot_20deg')
ax.plot(norm_w, norm_n_R_30, label='Rrot_30deg')
""" ax.plot(norm_w, norm_n_R_40, label='Rrot_40deg')
ax.plot(norm_w, norm_n_R_50, label='Rrot_50deg')
ax.plot(norm_w, norm_n_R_60, label='Rrot_60deg')
ax.plot(norm_w, norm_n_R_70, label='Rrot_70deg')
ax.plot(norm_w, norm_n_R_80, label='Rrot_80deg') """
ax.set_xlabel('normalized frequency [$fce$]')
ax.set_ylabel('normalized square of refractive index [fce]')
ax.set_title('normalized square of refractive index vs normalized frequency')
ax.legend()
plt.xlim(0.8, 1.3)
plt.ylim(-0.0001, 0.0002)
plt.legend(loc='upper right')
plt.show()

# %%
pp.omega_e['value']
# Out:
# -85439.56043956045

# %%
fig, ax = plt.subplots()
ax.plot(norm_w, norm_n_L_0, label='Lrot_0deg')
ax.plot(norm_w, norm_n_R_0, label='Rrot_0deg')
ax.set_xlabel('normalized frequency [$fce$]')
ax.set_ylabel('normalized square of refractive index [fce]')
ax.set_title('normalized square of refractive index vs normalized frequency')
ax.legend()
#plt.xlim(0.8, 1.3)
plt.ylim(-0.0001, 0.0002)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# 伝搬角が大きいほど電子サイクロトロン共鳴が低い周波数で生じている

# %%
norm_k_R_0 = cdr.dispersion_relation(f, n_R_0) 
norm_k_R_10 = cdr.dispersion_relation(f, n_R_10)
norm_k_R_20 = cdr.dispersion_relation(f, n_R_20)
norm_k_R_30 = cdr.dispersion_relation(f, n_R_30)
norm_k_R_40 = cdr.dispersion_relation(f, n_R_40)
norm_k_R_50 = cdr.dispersion_relation(f, n_R_50)
norm_k_R_60 = cdr.dispersion_relation(f, n_R_60)
norm_k_R_70 = cdr.dispersion_relation(f, n_R_70)
norm_k_R_80 = cdr.dispersion_relation(f, n_R_80)
# Out:
# /home/jackkooki/Document/duct_analysis/basic/calc_dispersion_relation.py:115: RuntimeWarning: invalid value encountered in sqrt
#   norm_k = np.sqrt(squared_norm_k)

# %%
fig, ax = plt.subplots()
ax.plot(norm_k_R_0, norm_w, label='Rrot_0deg')
ax.plot(norm_k_R_10, norm_w, label='Rrot_10deg')
ax.plot(norm_k_R_20, norm_w, label='Rrot_20deg')
ax.plot(norm_k_R_30, norm_w, label='Rrot_30deg')
ax.plot(norm_k_R_40, norm_w, label='Rrot_40deg')
ax.plot(norm_k_R_50, norm_w, label='Rrot_50deg')
ax.plot(norm_k_R_60, norm_w, label='Rrot_60deg')
ax.plot(norm_k_R_70, norm_w, label='Rrot_70deg')
ax.plot(norm_k_R_80, norm_w, label='Rrot_80deg')
ax.set_xlabel('normalized wave number [$1/\Omega_c$]')
ax.set_ylabel('normalized frequency [$\Omega_c$]')
ax.set_title('normalized frequency vs normalized wave number')
ax.legend()
#plt.xscale('log')
plt.xlim(0, 5e-4)
plt.ylim(0, 1.1)
plt.legend(loc='upper right')
plt.show()

# %%
import numpy as np
import calc_dispersion_relation as cdr
import plasma_params as pp
import matplotlib.pyplot as plt


Ey_to_Ex_0, Ez_to_Ex_0, By_to_Bx_0, Bz_to_Bx_0, E_to_cB_0 = cdr.calc_amp_ratio(n_R_0**2, S_0, D_0, P_0, 0)

Ey_to_Ex_10, Ez_to_Ex_10, By_to_Bx_10, Bz_to_Bx_10, E_to_cB_10 = cdr.calc_amp_ratio(n_R_10**2, S_10, D_10, P_10, 10)

Ey_to_Ex_20, Ez_to_Ex_20, By_to_Bx_20, Bz_to_Bx_20, E_to_cB_20 = cdr.calc_amp_ratio(n_R_20**2, S_20, D_20, P_20, 20)

Ey_to_Ex_30, Ez_to_Ex_30, By_to_Bx_30, Bz_to_Bx_30, E_to_cB_30 = cdr.calc_amp_ratio(n_R_30**2, S_30, D_30, P_30, 30)

Ey_to_Ex_40, Ez_to_Ex_40, By_to_Bx_40, Bz_to_Bx_40, E_to_cB_40 = cdr.calc_amp_ratio(n_R_40**2, S_40, D_40, P_40, 40)

Ey_to_Ex_50, Ez_to_Ex_50, By_to_Bx_50, Bz_to_Bx_50, E_to_cB_50 = cdr.calc_amp_ratio(n_R_50**2, S_50, D_50, P_50, 50)

Ey_to_Ex_60, Ez_to_Ex_60, By_to_Bx_60, Bz_to_Bx_60, E_to_cB_60 = cdr.calc_amp_ratio(n_R_60**2, S_60, D_60, P_60, 60)

Ey_to_Ex_70, Ez_to_Ex_70, By_to_Bx_70, Bz_to_Bx_70, E_to_cB_70 = cdr.calc_amp_ratio(n_R_70**2, S_70, D_70, P_70, 70)

Ey_to_Ex_80, Ez_to_Ex_80, By_to_Bx_80, Bz_to_Bx_80, E_to_cB_80 = cdr.calc_amp_ratio(n_R_80**2, S_80, D_80, P_80, 80)

# %%
fig, ax = plt.subplots()
ax.plot(norm_w, E_to_cB_0, label='0 deg')
ax.plot(norm_w, E_to_cB_10, label='10 deg')
ax.plot(norm_w, E_to_cB_20, label='20 deg')
ax.plot(norm_w, E_to_cB_30, label='30 deg')
ax.plot(norm_w, E_to_cB_40, label='40 deg')
ax.plot(norm_w, E_to_cB_50, label='50 deg')
ax.plot(norm_w, E_to_cB_60, label='60 deg')
ax.plot(norm_w, E_to_cB_70, label='70 deg')
ax.plot(norm_w, E_to_cB_80, label='80 deg')
ax.set_xlabel('normalized frequency [$\Omega_c$]')
ax.set_ylabel('E/cB')
ax.legend()
plt.xlim(0, 1.1)
plt.ylim(0, 500)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(norm_w, E_to_cB_0, label='0 deg')
ax.plot(norm_w, E_to_cB_10, label='10 deg')
ax.plot(norm_w, E_to_cB_20, label='20 deg')
ax.plot(norm_w, E_to_cB_30, label='30 deg')
ax.plot(norm_w, E_to_cB_40, label='40 deg')
ax.plot(norm_w, E_to_cB_50, label='50 deg')
ax.plot(norm_w, E_to_cB_60, label='60 deg')
ax.plot(norm_w, E_to_cB_70, label='70 deg')
ax.plot(norm_w, E_to_cB_80, label='80 deg')
ax.set_xlabel('normalized frequency [$\Omega_c$]')
ax.set_ylabel('E/cB')
ax.legend()
plt.xlim(0, 8)
plt.ylim(0, 2000)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(norm_w, E_to_cB_0, label='0 deg')
ax.plot(norm_w, E_to_cB_10, label='10 deg')
ax.plot(norm_w, E_to_cB_20, label='20 deg')
ax.plot(norm_w, E_to_cB_30, label='30 deg')
ax.plot(norm_w, E_to_cB_40, label='40 deg')
ax.plot(norm_w, E_to_cB_50, label='50 deg')
ax.plot(norm_w, E_to_cB_60, label='60 deg')
ax.plot(norm_w, E_to_cB_70, label='70 deg')
ax.plot(norm_w, E_to_cB_80, label='80 deg')
ax.set_xlabel('normalized frequency [$\Omega_c$]')
ax.set_ylabel('E/cB')
ax.legend()
plt.xlim(0, 1.1)
plt.ylim(0, 1)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(norm_w, E_to_cB_80, label='80 deg')
ax.set_xlabel('normalized frequency [$\Omega_c$]')
ax.set_ylabel('E/cB')
ax.legend()
plt.xlim(0, 8)
plt.ylim(0, 2000)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(norm_w, E_to_cB_70, label='70 deg')
ax.set_xlabel('normalized frequency [$\Omega_c$]')
ax.set_ylabel('E/cB')
ax.legend()
plt.xlim(0, 8)
plt.ylim(0, 2000)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(norm_w, E_to_cB_0, label='0 deg')
ax.set_xlabel('norm_w [$\Omega_c$]')
ax.set_ylabel('E/cB')
ax.legend()
plt.xlim(0, 1.1)
plt.ylim(0, 500)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(norm_w, E_to_cB_10, label='10 deg')
ax.set_xlabel('norm_w [\Omega_c]')
ax.set_ylabel('E/cB')
ax.legend()
plt.xlim(0, 1.1)
plt.ylim(0, 500)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(norm_w, E_to_cB_20, label='20 deg')
ax.set_xlabel('norm_w [\Omega_c]')
ax.set_ylabel('E/cB')
ax.legend()
plt.xlim(0, 1.1)
plt.ylim(0, 500)
plt.show()
