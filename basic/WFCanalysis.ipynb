# %%
import pyspedas
import pytplot
import numpy as np

# %%
tr=['2017-03-29', '2017-03-30']
from pyspedas.erg import pwe_wfc
pwe_wfc(trange=tr, datatype='waveform')
# Out:
# 03-Jul-23 17:19:01: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/wfc/l2/waveform/2017/03/
# 03-Jul-23 17:19:02: Downloading https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/wfc/l2/waveform/2017/03/erg_pwe_wfc_l2_e_waveform_65khz_sgi_2017032900_v01_01.cdf to erg_data/satellite/erg/pwe/wfc/l2/waveform/2017/03/erg_pwe_wfc_l2_e_waveform_65khz_sgi_2017032900_v01_01.cdf
# 03-Jul-23 17:20:22: Download complete: erg_data/satellite/erg/pwe/wfc/l2/waveform/2017/03/erg_pwe_wfc_l2_e_waveform_65khz_sgi_2017032900_v01_01.cdf
# 03-Jul-23 17:20:22: Downloading https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/wfc/l2/waveform/2017/03/erg_pwe_wfc_l2_e_waveform_65khz_sgi_2017032901_v01_01.cdf to erg_data/satellite/erg/pwe/wfc/l2/waveform/2017/03/erg_pwe_wfc_l2_e_waveform_65khz_sgi_2017032901_v01_01.cdf
# ...

# %%
pytplot.data_quants['erg_pwe_wfc_l2_b_65khz_Bx_waveform']
# Out:
# <xarray.DataArray 'erg_pwe_wfc_l2_b_65khz_Bx_waveform' (time: 52633600)>
# array([       nan,        nan,        nan, ...,  7.0296993, -1.945113 ,
#        -6.4091787], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 2017-03-29T00:02:55.804144 ... 2017-03-29T...
# Attributes:
#     CDF:           {'VATT': {'FIELDNAM': 'Bx waveform (SGI)', 'CATDESC': 'Bx ...
#     data_att:      {'coord_sys': '', 'units': 'pT', 'depend_1_units': 'ms', '...
#     plot_options:  {'xaxis_opt': {'axis_label': 'Time', 'crosshair': 'X', 'x_...
