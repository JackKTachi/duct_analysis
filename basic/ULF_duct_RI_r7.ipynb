# %%
import plot_B1oscillation as pbo

tr =['2017-03-27 21:30:00', '2017-03-27 22:00:00']
pbo.plotB1(tr, 600)
# Out:
# 04-Jul-23 18:42:26: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/03/
# 04-Jul-23 18:42:26: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/03/erg_pwe_ofa_l2_spec_20170327_v02_03.cdf
# 04-Jul-23 18:42:27: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
import ULF_duct_plot_detail as udp
import calc_integral_chorus as cic
import ULF_duct_plot_ver2 as udp2

download_trange = ['2017-03-27', '2017-03-28']

'ne_mgf',\
        'kvec_polar_132',\
        'erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_E_spectra_132',\
        'erg_mepe_l2_omniflux_FEDO',\
        'erg_mepe_l3_pa_FEDU_87.5keV', 'erg_mepe_l3_pa_FEDU_72.6keV', 'erg_mepe_l3_pa_FEDU_60.4keV','erg_mepe_l3_pa_FEDU_50.3keV', 'erg_mepe_l3_pa_FEDU_42.0keV','erg_mepe_l3_pa_FEDU_35.0keV','erg_mepe_l3_pa_FEDU_29.3keV','erg_mepe_l3_pa_FEDU_24.5keV','erg_mepe_l3_pa_FEDU_20.5keV','erg_mepe_l3_pa_FEDU_17.1keV','erg_mepe_l3_pa_FEDU_14.3keV','erg_mepe_l3_pa_FEDU_12.0keV',\
            'delta_z', 'erg_mgf_l2_magt_8sec','erg_mgf_l2_mag_8sec_MAF_x&y',\
            'erg_orb_l2_pos_rmlatmlt','erg_orb_l2_pos_eq' == udp2.ULF_duct_load(download_trange)
# Out:
# 10-Jun-23 23:07:37: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/03/
# 10-Jun-23 23:07:37: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/03/erg_pwe_ofa_l2_spec_20170327_v02_03.cdf
# 10-Jun-23 23:07:37: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
import pytplot
import pyspedas
import plasma_params as pp
import numpy as np
theta = 0
r7 = ['2017-03-27 21:30:00', '2017-03-27 22:00:00']
min = 0.1
max = 20
#'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r7, min, max)
plot_trange = r7
f=0.6e3
lst = download_trange[0].split('-')
#pytplot.cdf_to_tplot('./erg_data/satellite/erg/pwe/hfa/l3/1min/'+lst[0]+'/'+lst[1]+'/erg_pwe_hfa_l3_1min_'+lst[0]+lst[1]+lst[2]+'_v03_07.cdf')
#pyspedas.tinterpol('ne_mgf', 'erg_mgf_l2_magt_8sec', newname='ne_mgf_interpolated')
B = pytplot.data_quants['erg_mgf_l2_magt_8sec']*1e-9
#N = pytplot.data_quants['ne_mgf_interpolated']*1e6
fc = ((pp.Q*B*f/pp.ME)**(1/2))/2/np.pi
#fp = ((80.6*N)**(1/2))/2/np.pi
#re_in = fp/(fc*f*(np.cos(theta)-f/fc))**0.5  

N0 = 2e6
fp0 = ((80.6*N0)**(1/2))/2/np.pi
re_in_ = fp0/(fc*f*(np.cos(theta)-f/fc))**0.5 
pytplot.store_data('re_in_', data={'x': pytplot.data_quants['erg_mgf_l2_magt_8sec']['time'], 'y': re_in_})
pytplot.options('re_in_', opt_dict={'ytitle':'$RI(N0)$','ylog':0})    
#pytplot.store_data('re_in', data={'x': pytplot.data_quants['ne_mgf_interpolated']['time'], 'y': re_in})
#pytplot.options('re_in', opt_dict={'ytitle':'$RI (Ntime)$','ylog':0})
labels = pytplot.split_vec( 'erg_orb_l2_pos_rmlatmlt' )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_x', opt_dict={'ytitle':'L [Re]','ytitle_location':'left'} )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_y', 'ytitle', 'MLat [deg]' )
pytplot.options( 'erg_orb_l2_pos_rmlatmlt_z', 'ytitle', 'MLT [h]' )
pytplot.options('ne_mgf', opt_dict={'ytitle':'density','ylog':0})
pytplot.xlim( plot_trange[0], plot_trange[1] )


pytplot.tplot(['kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate','re_in_', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y'])

theta = 0
plot_trange = r7
#udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)

# %%
r7_1 = ['2017-03-27 22:00:00', '2017-03-27 22:30:00']
min = 0.1
max = 20
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r7_1, min, max)

f=0.3e3

theta = 0
plot_trange = r7_1
udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)
# Out:
# 10-Jun-23 22:47:37: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/03/
# 10-Jun-23 22:47:37: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/03/erg_pwe_ofa_l2_spec_20170327_v02_03.cdf
# 10-Jun-23 22:47:37: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
r7_2 = ['2017-03-27 22:30:00', '2017-03-27 23:00:00']
min = 0.1
max = 20
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r7_2, min, max)



theta = 0
plot_trange = r7_2
udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)
# Out:
# 10-Jun-23 22:37:21: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/03/
# 10-Jun-23 22:37:21: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/03/erg_pwe_ofa_l2_spec_20170327_v02_03.cdf
# 10-Jun-23 22:37:21: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
r7_3 = ['2017-03-27 20:00:00', '2017-03-27 20:30:00']
min = 0.1
max = 20
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r7_3, min, max)



theta = 0
plot_trange = r7_3
udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)
# Out:
# 10-Jun-23 22:25:58: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/03/
# 10-Jun-23 22:25:58: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/03/erg_pwe_ofa_l2_spec_20170327_v02_03.cdf
# 10-Jun-23 22:25:59: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
r7_4 = ['2017-03-27 20:30:00', '2017-03-27 21:00:00']
min = 0.1
max = 20
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r7_4, min, max)



theta = 0
plot_trange = r7_4
udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)
# Out:
# 10-Jun-23 22:29:45: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/03/
# 10-Jun-23 22:29:45: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/03/erg_pwe_ofa_l2_spec_20170327_v02_03.cdf
# 10-Jun-23 22:29:46: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...

# %%
r7_5 = ['2017-03-27 21:00:00', '2017-03-27 21:30:00']
min = 0.1
max = 20
'erg_pwe_ofa_l2_spec_B_chorus_integrate' == cic.integral_chorus_spec(download_trange,r7_5, min, max)



theta = 0
plot_trange = r7_5
udp.kvec_Bspec_intgrl_rein_delB_magt_Bxy('kvec_polar_132','erg_pwe_ofa_l2_spec_B_spectra_132','erg_pwe_ofa_l2_spec_B_chorus_integrate', 'delta_z',  'erg_mgf_l2_magt_8sec', 'erg_mgf_l2_mag_8sec_MAF_x&y','erg_orb_l2_pos_rmlatmlt',plot_trange=plot_trange,download_trange=download_trange,f=f ,theta=theta)
# Out:
# 10-Jun-23 22:33:31: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/03/
# 10-Jun-23 22:33:31: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/03/erg_pwe_ofa_l2_spec_20170327_v02_03.cdf
# 10-Jun-23 22:33:32: /home/jackkooki/Document/duct_analysis/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# ...
